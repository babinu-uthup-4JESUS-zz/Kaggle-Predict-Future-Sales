# %% [markdown]
# ### Summary
#
# Build a model using xgboost and verify it's performance on the validation set.

# %%
import pandas as pd
import xgboost as xgb
import numpy as np
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ##### Get relevant data in monthly form

# %%
sales_train = pd.read_csv('input/sales_train.csv')

# %%
monthly_sales_data = sales_train[['date_block_num', 'shop_id', 'item_id', 'item_cnt_day']].groupby(
    ['date_block_num', 'shop_id', 'item_id']).sum()
monthly_sales_data.rename(columns={'item_cnt_day':'item_cnt_month'}, inplace=True)
monthly_sales_data.reset_index(['date_block_num', 'shop_id', 'item_id'], inplace=True)

# %%
monthly_sales_data.columns
# Out:
# Index(['date_block_num', 'shop_id', 'item_id', 'item_cnt_month'], dtype='object')

# %%
items = pd.read_csv('input/items.csv')

# %%
items.columns
# Out:
# Index(['item_name', 'item_id', 'item_category_id'], dtype='object')

# %%
item_id_to_item_category_id = dict(zip(items.item_id, items.item_category_id))

# %%
monthly_sales_data['item_category_id'] = monthly_sales_data['item_id'].apply(lambda x : item_id_to_item_category_id.get(x, -1))

# %%
train_data = monthly_sales_data[(monthly_sales_data.date_block_num != 32) &(monthly_sales_data.date_block_num != 33)]
validation_data = monthly_sales_data[monthly_sales_data.date_block_num == 32]
test_data = monthly_sales_data[monthly_sales_data.date_block_num == 33]

# %% [markdown]
# ##### Get started with xgboost.

# %%
Y_COLUMN = 'item_cnt_month'
X_COLUMNS = [col for col in monthly_sales_data.columns if col != Y_COLUMN]

# %%
Y = train_data[[Y_COLUMN]]
X = train_data[X_COLUMNS]

# %%
xgb_train_data = xgb.DMatrix(X, Y, feature_names=X_COLUMNS)

# %%
xgb_params = {'eta' : 0.1}

# %%
model_1 = xgb.train(params=xgb_params,
                    dtrain=xgb_train_data,
                    num_boost_round=100)

# %%
model_1

# %%
new_X = validation_data[X_COLUMNS]
new_Y = validation_data[[Y_COLUMN]]

# %%
xgb_validation_data = xgb.DMatrix(new_X, feature_names=X_COLUMNS)

# %%
validation_predictions = model_1.predict(xgb_validation_data)

# %%
np.sqrt(mean_squared_error(np.clip(validation_predictions, 0 , 20),  np.clip(new_Y, 0, 20)))
# Out:
# 2.3387417865406737

# %% [markdown]
# ##### That looks encouraging. This is the best of what we have seen so far. Let us try training the model a bit further.

# %%
xgb_params = {'eta' : 0.01}

# %%
model_1 = xgb.train(params=xgb_params,
                    dtrain=xgb_train_data,
                    num_boost_round=1000)

# %%
validation_predictions = model_1.predict(xgb_validation_data)

# %%
np.sqrt(mean_squared_error(np.clip(validation_predictions, 0 , 20),  np.clip(new_Y, 0, 20)))
# Out:
# 2.3200486166464533

# %% [markdown]
# ##### Okay that looks to be showing diminishing returns and let us see early stopping would help us. Note, however that because of clipping, this may not offer us the best solution, but should be reasonably close. Let us go on !

# %%
xgb_validation_data = xgb.DMatrix(new_X, new_Y, feature_names=X_COLUMNS)

# %%
xgb_params = {'eta' : 0.01, 'eval_metric' : 'rmse'}

# %%
model_1 = xgb.train(params=xgb_params,
                    dtrain=xgb_train_data,
                    num_boost_round=1000,
                    evals=[(xgb_validation_data, 'eval')],
                    early_stopping_rounds=5)
# Out:
# [0]	eval-rmse:18.5338
# Will train until eval-rmse hasn't improved in 5 rounds.
# [1]	eval-rmse:18.518
# [2]	eval-rmse:18.5026
# [3]	eval-rmse:18.4876
# [4]	eval-rmse:18.4735
# [5]	eval-rmse:18.4592
# [6]	eval-rmse:18.4458
# [7]	eval-rmse:18.4321
# [8]	eval-rmse:18.4187
# [9]	eval-rmse:18.4062
# [10]	eval-rmse:18.3934
# [11]	eval-rmse:18.3809
# [12]	eval-rmse:18.3688
# [13]	eval-rmse:18.357
# [14]	eval-rmse:18.3461
# [15]	eval-rmse:18.3348
# [16]	eval-rmse:18.3239
# [17]	eval-rmse:18.3136
# [18]	eval-rmse:18.3056
# [19]	eval-rmse:18.2953
# [20]	eval-rmse:18.288
# [21]	eval-rmse:18.2782
# [22]	eval-rmse:18.2709
# [23]	eval-rmse:18.2615
# [24]	eval-rmse:18.2546
# [25]	eval-rmse:18.2461
# [26]	eval-rmse:18.2395
# [27]	eval-rmse:18.2308
# [28]	eval-rmse:18.2241
# [29]	eval-rmse:18.2183
# [30]	eval-rmse:18.2102
# [31]	eval-rmse:18.2035
# [32]	eval-rmse:18.1949
# [33]	eval-rmse:18.189
# [34]	eval-rmse:18.1806
# [35]	eval-rmse:18.175
# [36]	eval-rmse:18.1676
# [37]	eval-rmse:18.162
# [38]	eval-rmse:18.1542
# [39]	eval-rmse:18.1495
# [40]	eval-rmse:18.1422
# [41]	eval-rmse:18.1374
# [42]	eval-rmse:18.1303
# [43]	eval-rmse:18.1241
# [44]	eval-rmse:18.118
# [45]	eval-rmse:18.1125
# [46]	eval-rmse:18.1067
# [47]	eval-rmse:18.1026
# [48]	eval-rmse:18.0985
# [49]	eval-rmse:18.0946
# [50]	eval-rmse:18.0896
# [51]	eval-rmse:18.0858
# [52]	eval-rmse:18.0818
# [53]	eval-rmse:18.077
# [54]	eval-rmse:18.0732
# [55]	eval-rmse:18.0699
# [56]	eval-rmse:18.0663
# [57]	eval-rmse:18.063
# [58]	eval-rmse:18.0595
# [59]	eval-rmse:18.0562
# [60]	eval-rmse:18.0528
# [61]	eval-rmse:18.05
# [62]	eval-rmse:18.0468
# [63]	eval-rmse:18.0423
# [64]	eval-rmse:18.0391
# [65]	eval-rmse:18.0361
# [66]	eval-rmse:18.0331
# [67]	eval-rmse:18.0288
# [68]	eval-rmse:18.026
# [69]	eval-rmse:18.0231
# [70]	eval-rmse:18.0203
# [71]	eval-rmse:18.0177
# [72]	eval-rmse:18.0149
# [73]	eval-rmse:18.011
# [74]	eval-rmse:18.0084
# [75]	eval-rmse:18.0059
# [76]	eval-rmse:18.0018
# [77]	eval-rmse:17.9981
# [78]	eval-rmse:17.9941
# [79]	eval-rmse:17.9917
# [80]	eval-rmse:17.9866
# [81]	eval-rmse:17.9842
# [82]	eval-rmse:17.9805
# [83]	eval-rmse:17.9782
# [84]	eval-rmse:17.9745
# [85]	eval-rmse:17.9712
# [86]	eval-rmse:17.9676
# [87]	eval-rmse:17.9654
# [88]	eval-rmse:17.9619
# [89]	eval-rmse:17.9603
# [90]	eval-rmse:17.9557
# [91]	eval-rmse:17.9537
# [92]	eval-rmse:17.9503
# [93]	eval-rmse:17.9484
# [94]	eval-rmse:17.9465
# [95]	eval-rmse:17.9415
# [96]	eval-rmse:17.9396
# [97]	eval-rmse:17.9357
# [98]	eval-rmse:17.9337
# [99]	eval-rmse:17.9299
# [100]	eval-rmse:17.927
# [101]	eval-rmse:17.9252
# [102]	eval-rmse:17.9215
# [103]	eval-rmse:17.9196
# [104]	eval-rmse:17.9163
# [105]	eval-rmse:17.9136
# [106]	eval-rmse:17.9126
# [107]	eval-rmse:17.9096
# [108]	eval-rmse:17.907
# [109]	eval-rmse:17.9054
# [110]	eval-rmse:17.901
# [111]	eval-rmse:17.8993
# [112]	eval-rmse:17.8963
# [113]	eval-rmse:17.8953
# [114]	eval-rmse:17.892
# [115]	eval-rmse:17.8894
# [116]	eval-rmse:17.8886
# [117]	eval-rmse:17.8875
# [118]	eval-rmse:17.8834
# [119]	eval-rmse:17.8824
# [120]	eval-rmse:17.8784
# [121]	eval-rmse:17.8774
# [122]	eval-rmse:17.8739
# [123]	eval-rmse:17.873
# [124]	eval-rmse:17.8712
# [125]	eval-rmse:17.8703
# [126]	eval-rmse:17.8671
# [127]	eval-rmse:17.8661
# [128]	eval-rmse:17.8627
# [129]	eval-rmse:17.8613
# [130]	eval-rmse:17.8605
# [131]	eval-rmse:17.8571
# [132]	eval-rmse:17.8563
# [133]	eval-rmse:17.8548
# [134]	eval-rmse:17.8517
# [135]	eval-rmse:17.8507
# [136]	eval-rmse:17.85
# [137]	eval-rmse:17.8468
# [138]	eval-rmse:17.8461
# [139]	eval-rmse:17.8431
# [140]	eval-rmse:17.842
# [141]	eval-rmse:17.8398
# [142]	eval-rmse:17.8382
# [143]	eval-rmse:17.8373
# [144]	eval-rmse:17.8366
# [145]	eval-rmse:17.8338
# [146]	eval-rmse:17.8329
# [147]	eval-rmse:17.83
# [148]	eval-rmse:17.8288
# [149]	eval-rmse:17.8274
# [150]	eval-rmse:17.8268
# [151]	eval-rmse:17.8242
# [152]	eval-rmse:17.823
# [153]	eval-rmse:17.8221
# [154]	eval-rmse:17.8217
# [155]	eval-rmse:17.8204
# [156]	eval-rmse:17.8192
# [157]	eval-rmse:17.8172
# [158]	eval-rmse:17.8168
# [159]	eval-rmse:17.8156
# [160]	eval-rmse:17.8152
# [161]	eval-rmse:17.8132
# [162]	eval-rmse:17.8128
# [163]	eval-rmse:17.8119
# [164]	eval-rmse:17.8112
# [165]	eval-rmse:17.8109
# [166]	eval-rmse:17.8098
# [167]	eval-rmse:17.8093
# [168]	eval-rmse:17.8075
# [169]	eval-rmse:17.806
# [170]	eval-rmse:17.8054
# [171]	eval-rmse:17.8044
# [172]	eval-rmse:17.8033
# [173]	eval-rmse:17.8026
# [174]	eval-rmse:17.8023
# [175]	eval-rmse:17.8009
# [176]	eval-rmse:17.8006
# [177]	eval-rmse:17.8002
# [178]	eval-rmse:17.7993
# [179]	eval-rmse:17.7983
# [180]	eval-rmse:17.7981
# [181]	eval-rmse:17.7976
# [182]	eval-rmse:17.7963
# [183]	eval-rmse:17.7952
# [184]	eval-rmse:17.7935
# [185]	eval-rmse:17.7925
# [186]	eval-rmse:17.7915
# [187]	eval-rmse:17.7912
# [188]	eval-rmse:17.789
# [189]	eval-rmse:17.7888
# [190]	eval-rmse:17.7878
# [191]	eval-rmse:17.7869
# [192]	eval-rmse:17.786
# [193]	eval-rmse:17.7858
# [194]	eval-rmse:17.7848
# [195]	eval-rmse:17.7845
# [196]	eval-rmse:17.7824
# [197]	eval-rmse:17.7819
# [198]	eval-rmse:17.7807
# [199]	eval-rmse:17.7795
# [200]	eval-rmse:17.7788
# [201]	eval-rmse:17.7775
# [202]	eval-rmse:17.777
# [203]	eval-rmse:17.7761
# [204]	eval-rmse:17.775
# [205]	eval-rmse:17.7744
# [206]	eval-rmse:17.773
# [207]	eval-rmse:17.7727
# [208]	eval-rmse:17.7716
# [209]	eval-rmse:17.7713
# [210]	eval-rmse:17.7704
# [211]	eval-rmse:17.77
# [212]	eval-rmse:17.7688
# [213]	eval-rmse:17.7681
# [214]	eval-rmse:17.7663
# [215]	eval-rmse:17.7656
# [216]	eval-rmse:17.7648
# [217]	eval-rmse:17.7637
# [218]	eval-rmse:17.7629
# [219]	eval-rmse:17.7592
# [220]	eval-rmse:17.7557
# [221]	eval-rmse:17.755
# [222]	eval-rmse:17.7543
# [223]	eval-rmse:17.7537
# [224]	eval-rmse:17.75
# [225]	eval-rmse:17.7491
# [226]	eval-rmse:17.7491
# [227]	eval-rmse:17.749
# [228]	eval-rmse:17.7452
# [229]	eval-rmse:17.742
# [230]	eval-rmse:17.7411
# [231]	eval-rmse:17.7374
# [232]	eval-rmse:17.7372
# [233]	eval-rmse:17.734
# [234]	eval-rmse:17.7337
# [235]	eval-rmse:17.7327
# [236]	eval-rmse:17.7323
# [237]	eval-rmse:17.7322
# [238]	eval-rmse:17.7319
# [239]	eval-rmse:17.7285
# [240]	eval-rmse:17.7282
# [241]	eval-rmse:17.7281
# [242]	eval-rmse:17.7277
# [243]	eval-rmse:17.7277
# [244]	eval-rmse:17.7273
# [245]	eval-rmse:17.7272
# [246]	eval-rmse:17.7219
# [247]	eval-rmse:17.7216
# [248]	eval-rmse:17.7162
# [249]	eval-rmse:17.7159
# [250]	eval-rmse:17.7107
# [251]	eval-rmse:17.7104
# [252]	eval-rmse:17.7103
# [253]	eval-rmse:17.71
# [254]	eval-rmse:17.7048
# [255]	eval-rmse:17.7045
# [256]	eval-rmse:17.6993
# [257]	eval-rmse:17.699
# [258]	eval-rmse:17.6939
# [259]	eval-rmse:17.6938
# [260]	eval-rmse:17.6935
# [261]	eval-rmse:17.6885
# [262]	eval-rmse:17.6882
# [263]	eval-rmse:17.6881
# [264]	eval-rmse:17.6878
# [265]	eval-rmse:17.6869
# [266]	eval-rmse:17.6869
# [267]	eval-rmse:17.6866
# [268]	eval-rmse:17.6816
# [269]	eval-rmse:17.6813
# [270]	eval-rmse:17.6813
# [271]	eval-rmse:17.6804
# [272]	eval-rmse:17.6801
# [273]	eval-rmse:17.6801
# [274]	eval-rmse:17.6794
# [275]	eval-rmse:17.6745
# [276]	eval-rmse:17.6742
# [277]	eval-rmse:17.6718
# [278]	eval-rmse:17.6712
# [279]	eval-rmse:17.6711
# [280]	eval-rmse:17.6705
# [281]	eval-rmse:17.6657
# [282]	eval-rmse:17.6654
# [283]	eval-rmse:17.6653
# [284]	eval-rmse:17.6644
# [285]	eval-rmse:17.6639
# [286]	eval-rmse:17.6638
# [287]	eval-rmse:17.6636
# [288]	eval-rmse:17.663
# [289]	eval-rmse:17.6591
# [290]	eval-rmse:17.659
# [291]	eval-rmse:17.6584
# [292]	eval-rmse:17.6583
# [293]	eval-rmse:17.6545
# [294]	eval-rmse:17.6499
# [295]	eval-rmse:17.6463
# [296]	eval-rmse:17.6462
# [297]	eval-rmse:17.646
# [298]	eval-rmse:17.6458
# [299]	eval-rmse:17.6444
# [300]	eval-rmse:17.6443
# [301]	eval-rmse:17.6427
# [302]	eval-rmse:17.6426
# [303]	eval-rmse:17.6421
# [304]	eval-rmse:17.6386
# [305]	eval-rmse:17.6386
# [306]	eval-rmse:17.6385
# [307]	eval-rmse:17.6349
# [308]	eval-rmse:17.6291
# [309]	eval-rmse:17.6257
# [310]	eval-rmse:17.6257
# [311]	eval-rmse:17.6252
# [312]	eval-rmse:17.6195
# [313]	eval-rmse:17.6162
# [314]	eval-rmse:17.616
# [315]	eval-rmse:17.616
# [316]	eval-rmse:17.6126
# [317]	eval-rmse:17.6111
# [318]	eval-rmse:17.6055
# [319]	eval-rmse:17.605
# [320]	eval-rmse:17.6019
# [321]	eval-rmse:17.6017
# [322]	eval-rmse:17.6015
# [323]	eval-rmse:17.6002
# [324]	eval-rmse:17.5947
# [325]	eval-rmse:17.5916
# [326]	eval-rmse:17.5915
# [327]	eval-rmse:17.591
# [328]	eval-rmse:17.5878
# [329]	eval-rmse:17.5861
# [330]	eval-rmse:17.5807
# [331]	eval-rmse:17.5803
# [332]	eval-rmse:17.5802
# [333]	eval-rmse:17.5786
# [334]	eval-rmse:17.5785
# [335]	eval-rmse:17.5755
# [336]	eval-rmse:17.5739
# [337]	eval-rmse:17.5686
# [338]	eval-rmse:17.5671
# [339]	eval-rmse:17.567
# [340]	eval-rmse:17.5669
# [341]	eval-rmse:17.5642
# [342]	eval-rmse:17.5642
# [343]	eval-rmse:17.5628
# [344]	eval-rmse:17.5598
# [345]	eval-rmse:17.5584
# [346]	eval-rmse:17.5583
# [347]	eval-rmse:17.5557
# [348]	eval-rmse:17.5528
# [349]	eval-rmse:17.5515
# [350]	eval-rmse:17.5514
# [351]	eval-rmse:17.55
# [352]	eval-rmse:17.55
# [353]	eval-rmse:17.5474
# [354]	eval-rmse:17.546
# [355]	eval-rmse:17.5434
# [356]	eval-rmse:17.5407
# [357]	eval-rmse:17.5395
# [358]	eval-rmse:17.5384
# [359]	eval-rmse:17.5372
# [360]	eval-rmse:17.537
# [361]	eval-rmse:17.5362
# [362]	eval-rmse:17.5361
# [363]	eval-rmse:17.5335
# [364]	eval-rmse:17.5334
# [365]	eval-rmse:17.5326
# [366]	eval-rmse:17.5301
# [367]	eval-rmse:17.5274
# [368]	eval-rmse:17.5266
# [369]	eval-rmse:17.5255
# [370]	eval-rmse:17.5247
# [371]	eval-rmse:17.5247
# [372]	eval-rmse:17.5221
# [373]	eval-rmse:17.5194
# [374]	eval-rmse:17.5168
# [375]	eval-rmse:17.5141
# [376]	eval-rmse:17.5133
# [377]	eval-rmse:17.5113
# [378]	eval-rmse:17.5086
# [379]	eval-rmse:17.5079
# [380]	eval-rmse:17.5066
# [381]	eval-rmse:17.5041
# [382]	eval-rmse:17.5034
# [383]	eval-rmse:17.5007
# [384]	eval-rmse:17.5
# [385]	eval-rmse:17.4999
# [386]	eval-rmse:17.4976
# [387]	eval-rmse:17.4969
# [388]	eval-rmse:17.4943
# [389]	eval-rmse:17.4924
# [390]	eval-rmse:17.4917
# [391]	eval-rmse:17.4905
# [392]	eval-rmse:17.4898
# [393]	eval-rmse:17.4872
# [394]	eval-rmse:17.4848
# [395]	eval-rmse:17.4842
# [396]	eval-rmse:17.4818
# [397]	eval-rmse:17.4818
# [398]	eval-rmse:17.4795
# [399]	eval-rmse:17.4789
# [400]	eval-rmse:17.4764
# [401]	eval-rmse:17.4742
# [402]	eval-rmse:17.4736
# [403]	eval-rmse:17.4726
# [404]	eval-rmse:17.4724
# [405]	eval-rmse:17.4711
# [406]	eval-rmse:17.4693
# [407]	eval-rmse:17.4669
# [408]	eval-rmse:17.4652
# [409]	eval-rmse:17.4639
# [410]	eval-rmse:17.4621
# [411]	eval-rmse:17.4614
# [412]	eval-rmse:17.4592
# [413]	eval-rmse:17.4586
# [414]	eval-rmse:17.4584
# [415]	eval-rmse:17.4576
# [416]	eval-rmse:17.4571
# [417]	eval-rmse:17.456
# [418]	eval-rmse:17.4539
# [419]	eval-rmse:17.4538
# [420]	eval-rmse:17.4536
# [421]	eval-rmse:17.4515
# [422]	eval-rmse:17.4511
# [423]	eval-rmse:17.451
# [424]	eval-rmse:17.4487
# [425]	eval-rmse:17.4486
# [426]	eval-rmse:17.4465
# [427]	eval-rmse:17.4457
# [428]	eval-rmse:17.4447
# [429]	eval-rmse:17.4431
# [430]	eval-rmse:17.4426
# [431]	eval-rmse:17.4422
# [432]	eval-rmse:17.4422
# [433]	eval-rmse:17.4419
# [434]	eval-rmse:17.4399
# [435]	eval-rmse:17.4398
# [436]	eval-rmse:17.4396
# [437]	eval-rmse:17.4376
# [438]	eval-rmse:17.4374
# [439]	eval-rmse:17.4374
# [440]	eval-rmse:17.4365
# [441]	eval-rmse:17.4346
# [442]	eval-rmse:17.4344
# [443]	eval-rmse:17.4343
# [444]	eval-rmse:17.4325
# [445]	eval-rmse:17.4317
# [446]	eval-rmse:17.4313
# [447]	eval-rmse:17.4312
# [448]	eval-rmse:17.4293
# [449]	eval-rmse:17.4291
# [450]	eval-rmse:17.4291
# [451]	eval-rmse:17.4281
# [452]	eval-rmse:17.4263
# [453]	eval-rmse:17.4261
# [454]	eval-rmse:17.426
# [455]	eval-rmse:17.426
# [456]	eval-rmse:17.4256
# [457]	eval-rmse:17.425
# [458]	eval-rmse:17.425
# [459]	eval-rmse:17.4247
# [460]	eval-rmse:17.4245
# [461]	eval-rmse:17.4245
# [462]	eval-rmse:17.4239
# [463]	eval-rmse:17.4237
# [464]	eval-rmse:17.4237
# [465]	eval-rmse:17.4234
# [466]	eval-rmse:17.4234
# [467]	eval-rmse:17.4234
# [468]	eval-rmse:17.4228
# [469]	eval-rmse:17.4227
# [470]	eval-rmse:17.4226
# [471]	eval-rmse:17.4216
# [472]	eval-rmse:17.4215
# [473]	eval-rmse:17.4214
# [474]	eval-rmse:17.4215
# [475]	eval-rmse:17.4215
# [476]	eval-rmse:17.4213
# [477]	eval-rmse:17.4204
# [478]	eval-rmse:17.4204
# [479]	eval-rmse:17.4204
# [480]	eval-rmse:17.4204
# [481]	eval-rmse:17.4195
# [482]	eval-rmse:17.4194
# [483]	eval-rmse:17.4193
# [484]	eval-rmse:17.4184
# [485]	eval-rmse:17.4184
# [486]	eval-rmse:17.4185
# [487]	eval-rmse:17.4183
# [488]	eval-rmse:17.4183
# [489]	eval-rmse:17.4175
# [490]	eval-rmse:17.4166
# [491]	eval-rmse:17.4165
# [492]	eval-rmse:17.4164
# [493]	eval-rmse:17.4164
# [494]	eval-rmse:17.4161
# [495]	eval-rmse:17.4161
# [496]	eval-rmse:17.416
# [497]	eval-rmse:17.416
# [498]	eval-rmse:17.4161
# [499]	eval-rmse:17.4161
# [500]	eval-rmse:17.4161
# [501]	eval-rmse:17.4151
# [502]	eval-rmse:17.4151
# [503]	eval-rmse:17.4151
# [504]	eval-rmse:17.4151
# [505]	eval-rmse:17.4149
# [506]	eval-rmse:17.4145
# [507]	eval-rmse:17.4145
# [508]	eval-rmse:17.4137
# [509]	eval-rmse:17.4137
# [510]	eval-rmse:17.4139
# [511]	eval-rmse:17.4136
# [512]	eval-rmse:17.4129
# [513]	eval-rmse:17.4129
# [514]	eval-rmse:17.4129
# [515]	eval-rmse:17.4126
# [516]	eval-rmse:17.4128
# [517]	eval-rmse:17.4128
# [518]	eval-rmse:17.4127
# [519]	eval-rmse:17.4123
# [520]	eval-rmse:17.4116
# [521]	eval-rmse:17.4116
# [522]	eval-rmse:17.4115
# [523]	eval-rmse:17.4114
# [524]	eval-rmse:17.4114
# [525]	eval-rmse:17.4114
# [526]	eval-rmse:17.4114
# [527]	eval-rmse:17.4112
# [528]	eval-rmse:17.4112
# [529]	eval-rmse:17.4112
# [530]	eval-rmse:17.4105
# [531]	eval-rmse:17.4105
# [532]	eval-rmse:17.4101
# [533]	eval-rmse:17.4101
# [534]	eval-rmse:17.41
# [535]	eval-rmse:17.4096
# [536]	eval-rmse:17.4096
# [537]	eval-rmse:17.4095
# [538]	eval-rmse:17.4094
# [539]	eval-rmse:17.4095
# [540]	eval-rmse:17.4088
# [541]	eval-rmse:17.4088
# [542]	eval-rmse:17.408
# [543]	eval-rmse:17.4078
# [544]	eval-rmse:17.4078
# [545]	eval-rmse:17.4077
# [546]	eval-rmse:17.4077
# [547]	eval-rmse:17.4071
# [548]	eval-rmse:17.4068
# [549]	eval-rmse:17.4068
# [550]	eval-rmse:17.4069
# [551]	eval-rmse:17.4067
# [552]	eval-rmse:17.4067
# [553]	eval-rmse:17.4067
# [554]	eval-rmse:17.4066
# [555]	eval-rmse:17.4065
# [556]	eval-rmse:17.406
# [557]	eval-rmse:17.4058
# [558]	eval-rmse:17.4054
# [559]	eval-rmse:17.4054
# [560]	eval-rmse:17.4054
# [561]	eval-rmse:17.4054
# [562]	eval-rmse:17.4053
# [563]	eval-rmse:17.4047
# [564]	eval-rmse:17.4038
# [565]	eval-rmse:17.4036
# [566]	eval-rmse:17.4036
# [567]	eval-rmse:17.4029
# [568]	eval-rmse:17.4027
# [569]	eval-rmse:17.4024
# [570]	eval-rmse:17.4022
# [571]	eval-rmse:17.4022
# [572]	eval-rmse:17.4022
# [573]	eval-rmse:17.4022
# [574]	eval-rmse:17.4013
# [575]	eval-rmse:17.4011
# [576]	eval-rmse:17.4011
# [577]	eval-rmse:17.4011
# [578]	eval-rmse:17.4011
# [579]	eval-rmse:17.401
# [580]	eval-rmse:17.401
# [581]	eval-rmse:17.4001
# [582]	eval-rmse:17.4
# [583]	eval-rmse:17.4
# [584]	eval-rmse:17.3994
# [585]	eval-rmse:17.3994
# [586]	eval-rmse:17.3994
# [587]	eval-rmse:17.3994
# [588]	eval-rmse:17.3992
# [589]	eval-rmse:17.3992
# [590]	eval-rmse:17.399
# [591]	eval-rmse:17.3989
# [592]	eval-rmse:17.3989
# [593]	eval-rmse:17.3989
# [594]	eval-rmse:17.3989
# [595]	eval-rmse:17.3988
# [596]	eval-rmse:17.3988
# [597]	eval-rmse:17.3987
# [598]	eval-rmse:17.3987
# [599]	eval-rmse:17.3987
# [600]	eval-rmse:17.3981
# [601]	eval-rmse:17.3973
# [602]	eval-rmse:17.3971
# [603]	eval-rmse:17.3971
# [604]	eval-rmse:17.3972
# [605]	eval-rmse:17.3972
# [606]	eval-rmse:17.3971
# [607]	eval-rmse:17.3971
# [608]	eval-rmse:17.3967
# [609]	eval-rmse:17.3966
# [610]	eval-rmse:17.3965
# [611]	eval-rmse:17.3965
# [612]	eval-rmse:17.3965
# [613]	eval-rmse:17.3965
# [614]	eval-rmse:17.3964
# [615]	eval-rmse:17.3958
# [616]	eval-rmse:17.3959
# [617]	eval-rmse:17.3958
# [618]	eval-rmse:17.3961
# [619]	eval-rmse:17.396
# [620]	eval-rmse:17.396
# Stopping. Best iteration:
# [615]	eval-rmse:17.3958

# %%
validation_predictions = model_1.predict(xgb_validation_data, ntree_limit=model_1.best_ntree_limit)

# %%
np.sqrt(mean_squared_error(np.clip(validation_predictions, 0, 20), np.clip(new_Y, 0, 20)))
# Out:
# 2.316780274224487

# %% [markdown]
# ##### Okay , that does not look to give us something now, but let us check the variable importance here.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize=(16, 9))
xgb.plot_importance(model_1, ax=ax)

# %% [markdown]
# ##### Let us try if cross validation helps us here. One may question the use of cross validation, since we are dealing with time series data, but we are not exactly treating this as a time series problem, but rather as a modelling problem with item_cnt_month and other parameters.

# %%
Y = train_data[[Y_COLUMN]]
X = train_data[X_COLUMNS]

# %%
xgb_train_data = xgb.DMatrix(X, Y, feature_names=X_COLUMNS)

# %%
xgb_params = {'eta' : 0.1, 'eval_metric' : 'rmse'}

# %%
model_1 = xgb.cv(params=xgb_params,
                 dtrain=xgb_train_data,
                 num_boost_round=1000,
                 nfold=5,
                 early_stopping_rounds=5,
                 callbacks=[xgb.callback.print_evaluation(show_stdv=False)])
# Out:
# [0]	train-rmse:7.99368	test-rmse:7.96755
# [1]	train-rmse:7.6766	test-rmse:7.65507
# [2]	train-rmse:7.40793	test-rmse:7.39184
# [3]	train-rmse:7.18181	test-rmse:7.17257
# [4]	train-rmse:6.98281	test-rmse:6.98576
# [5]	train-rmse:6.82234	test-rmse:6.82667
# [6]	train-rmse:6.6897	test-rmse:6.69962
# [7]	train-rmse:6.57976	test-rmse:6.59977
# [8]	train-rmse:6.48322	test-rmse:6.5101
# [9]	train-rmse:6.39822	test-rmse:6.43156
# [10]	train-rmse:6.32507	test-rmse:6.36505
# [11]	train-rmse:6.26638	test-rmse:6.313
# [12]	train-rmse:6.20237	test-rmse:6.25762
# [13]	train-rmse:6.15164	test-rmse:6.21604
# [14]	train-rmse:6.10977	test-rmse:6.18031
# [15]	train-rmse:6.07227	test-rmse:6.14751
# [16]	train-rmse:6.02941	test-rmse:6.11304
# [17]	train-rmse:5.99583	test-rmse:6.08269
# [18]	train-rmse:5.97154	test-rmse:6.06165
# [19]	train-rmse:5.93322	test-rmse:6.02932
# [20]	train-rmse:5.90095	test-rmse:5.997
# [21]	train-rmse:5.87228	test-rmse:5.9734
# [22]	train-rmse:5.82793	test-rmse:5.93602
# [23]	train-rmse:5.79579	test-rmse:5.91274
# [24]	train-rmse:5.7609	test-rmse:5.88522
# [25]	train-rmse:5.73344	test-rmse:5.86274
# [26]	train-rmse:5.70925	test-rmse:5.84397
# [27]	train-rmse:5.67978	test-rmse:5.82016
# [28]	train-rmse:5.65305	test-rmse:5.79308
# [29]	train-rmse:5.63599	test-rmse:5.78151
# [30]	train-rmse:5.61587	test-rmse:5.76206
# [31]	train-rmse:5.59465	test-rmse:5.7413
# [32]	train-rmse:5.57904	test-rmse:5.73152
# [33]	train-rmse:5.56064	test-rmse:5.71871
# [34]	train-rmse:5.54121	test-rmse:5.70195
# [35]	train-rmse:5.52865	test-rmse:5.6899
# [36]	train-rmse:5.51736	test-rmse:5.68228
# [37]	train-rmse:5.50054	test-rmse:5.6677
# [38]	train-rmse:5.48723	test-rmse:5.65573
# [39]	train-rmse:5.47686	test-rmse:5.64754
# [40]	train-rmse:5.46157	test-rmse:5.63205
# [41]	train-rmse:5.45029	test-rmse:5.62279
# [42]	train-rmse:5.43425	test-rmse:5.61135
# [43]	train-rmse:5.4236	test-rmse:5.60479
# [44]	train-rmse:5.4098	test-rmse:5.58961
# [45]	train-rmse:5.40201	test-rmse:5.58187
# [46]	train-rmse:5.38814	test-rmse:5.56682
# [47]	train-rmse:5.37848	test-rmse:5.55916
# [48]	train-rmse:5.36515	test-rmse:5.55013
# [49]	train-rmse:5.35815	test-rmse:5.5429
# [50]	train-rmse:5.34537	test-rmse:5.53119
# [51]	train-rmse:5.33563	test-rmse:5.52004
# [52]	train-rmse:5.328	test-rmse:5.50951
# [53]	train-rmse:5.31668	test-rmse:5.49863
# [54]	train-rmse:5.30567	test-rmse:5.49158
# [55]	train-rmse:5.29509	test-rmse:5.48286
# [56]	train-rmse:5.29114	test-rmse:5.48067
# [57]	train-rmse:5.28487	test-rmse:5.47526
# [58]	train-rmse:5.27802	test-rmse:5.4702
# [59]	train-rmse:5.27133	test-rmse:5.46641
# [60]	train-rmse:5.26061	test-rmse:5.45792
# [61]	train-rmse:5.25629	test-rmse:5.45394
# [62]	train-rmse:5.25121	test-rmse:5.45016
# [63]	train-rmse:5.24825	test-rmse:5.44729
# [64]	train-rmse:5.24096	test-rmse:5.44064
# [65]	train-rmse:5.23138	test-rmse:5.43504
# [66]	train-rmse:5.22703	test-rmse:5.43021
# [67]	train-rmse:5.22109	test-rmse:5.42597
# [68]	train-rmse:5.2173	test-rmse:5.42323
# [69]	train-rmse:5.21054	test-rmse:5.41827
# [70]	train-rmse:5.20388	test-rmse:5.41462
# [71]	train-rmse:5.19836	test-rmse:5.40954
# [72]	train-rmse:5.19354	test-rmse:5.40591
# [73]	train-rmse:5.18816	test-rmse:5.40247
# [74]	train-rmse:5.18318	test-rmse:5.39938
# [75]	train-rmse:5.17661	test-rmse:5.39532
# [76]	train-rmse:5.16845	test-rmse:5.39057
# [77]	train-rmse:5.16476	test-rmse:5.38577
# [78]	train-rmse:5.16097	test-rmse:5.38222
# [79]	train-rmse:5.1564	test-rmse:5.379
# [80]	train-rmse:5.14943	test-rmse:5.37441
# [81]	train-rmse:5.14361	test-rmse:5.3722
# [82]	train-rmse:5.13722	test-rmse:5.36607
# [83]	train-rmse:5.13143	test-rmse:5.36137
# [84]	train-rmse:5.12735	test-rmse:5.35872
# [85]	train-rmse:5.12321	test-rmse:5.3548
# [86]	train-rmse:5.11772	test-rmse:5.35147
# [87]	train-rmse:5.11417	test-rmse:5.3483
# [88]	train-rmse:5.10798	test-rmse:5.34495
# [89]	train-rmse:5.10267	test-rmse:5.33958
# [90]	train-rmse:5.09791	test-rmse:5.33652
# [91]	train-rmse:5.09367	test-rmse:5.3329
# [92]	train-rmse:5.0882	test-rmse:5.32659
# [93]	train-rmse:5.08643	test-rmse:5.32468
# [94]	train-rmse:5.08075	test-rmse:5.32047
# [95]	train-rmse:5.07546	test-rmse:5.31662
# [96]	train-rmse:5.07099	test-rmse:5.31313
# [97]	train-rmse:5.06687	test-rmse:5.30966
# [98]	train-rmse:5.05975	test-rmse:5.30557
# [99]	train-rmse:5.05637	test-rmse:5.3015
# [100]	train-rmse:5.05182	test-rmse:5.29823
# [101]	train-rmse:5.05036	test-rmse:5.29708
# [102]	train-rmse:5.04592	test-rmse:5.29592
# [103]	train-rmse:5.04241	test-rmse:5.29259
# [104]	train-rmse:5.03773	test-rmse:5.28888
# [105]	train-rmse:5.03409	test-rmse:5.28615
# [106]	train-rmse:5.02816	test-rmse:5.28327
# [107]	train-rmse:5.02233	test-rmse:5.27784
# [108]	train-rmse:5.01682	test-rmse:5.27342
# [109]	train-rmse:5.01371	test-rmse:5.27034
# [110]	train-rmse:5.00957	test-rmse:5.26782
# [111]	train-rmse:5.00559	test-rmse:5.26476
# [112]	train-rmse:5.00202	test-rmse:5.26182
# [113]	train-rmse:4.99561	test-rmse:5.2572
# [114]	train-rmse:4.99178	test-rmse:5.25608
# [115]	train-rmse:4.98632	test-rmse:5.25327
# [116]	train-rmse:4.9839	test-rmse:5.25105
# [117]	train-rmse:4.98167	test-rmse:5.24948
# [118]	train-rmse:4.97746	test-rmse:5.24404
# [119]	train-rmse:4.97505	test-rmse:5.24214
# [120]	train-rmse:4.97159	test-rmse:5.2403
# [121]	train-rmse:4.96544	test-rmse:5.23315
# [122]	train-rmse:4.96121	test-rmse:5.22886
# [123]	train-rmse:4.95905	test-rmse:5.22699
# [124]	train-rmse:4.95653	test-rmse:5.22515
# [125]	train-rmse:4.95249	test-rmse:5.21981
# [126]	train-rmse:4.95072	test-rmse:5.2184
# [127]	train-rmse:4.94957	test-rmse:5.21725
# [128]	train-rmse:4.94679	test-rmse:5.21589
# [129]	train-rmse:4.94385	test-rmse:5.21391
# [130]	train-rmse:4.94177	test-rmse:5.2123
# [131]	train-rmse:4.93878	test-rmse:5.20714
# [132]	train-rmse:4.93519	test-rmse:5.20537
# [133]	train-rmse:4.93132	test-rmse:5.2031
# [134]	train-rmse:4.92639	test-rmse:5.2004
# [135]	train-rmse:4.92178	test-rmse:5.19809
# [136]	train-rmse:4.91939	test-rmse:5.19665
# [137]	train-rmse:4.91451	test-rmse:5.19428
# [138]	train-rmse:4.91235	test-rmse:5.19203
# [139]	train-rmse:4.90751	test-rmse:5.19043
# [140]	train-rmse:4.90418	test-rmse:5.18738
# [141]	train-rmse:4.90125	test-rmse:5.18498
# [142]	train-rmse:4.89719	test-rmse:5.18275
# [143]	train-rmse:4.89327	test-rmse:5.17869
# [144]	train-rmse:4.88612	test-rmse:5.17542
# [145]	train-rmse:4.88428	test-rmse:5.1747
# [146]	train-rmse:4.88078	test-rmse:5.17327
# [147]	train-rmse:4.87906	test-rmse:5.17157
# [148]	train-rmse:4.87731	test-rmse:5.17071
# [149]	train-rmse:4.8732	test-rmse:5.16897
# [150]	train-rmse:4.86954	test-rmse:5.1671
# [151]	train-rmse:4.86612	test-rmse:5.1665
# [152]	train-rmse:4.86202	test-rmse:5.16388
# [153]	train-rmse:4.85886	test-rmse:5.16252
# [154]	train-rmse:4.85517	test-rmse:5.16069
# [155]	train-rmse:4.84998	test-rmse:5.15961
# [156]	train-rmse:4.84547	test-rmse:5.15727
# [157]	train-rmse:4.84352	test-rmse:5.15436
# [158]	train-rmse:4.8389	test-rmse:5.15267
# [159]	train-rmse:4.83661	test-rmse:5.1513
# [160]	train-rmse:4.8353	test-rmse:5.1501
# [161]	train-rmse:4.83142	test-rmse:5.14848
# [162]	train-rmse:4.82994	test-rmse:5.14715
# [163]	train-rmse:4.82617	test-rmse:5.14569
# [164]	train-rmse:4.82477	test-rmse:5.14396
# [165]	train-rmse:4.82127	test-rmse:5.14115
# [166]	train-rmse:4.81747	test-rmse:5.13949
# [167]	train-rmse:4.81608	test-rmse:5.13841
# [168]	train-rmse:4.81421	test-rmse:5.13695
# [169]	train-rmse:4.81054	test-rmse:5.13502
# [170]	train-rmse:4.8085	test-rmse:5.13391
# [171]	train-rmse:4.80635	test-rmse:5.13286
# [172]	train-rmse:4.80501	test-rmse:5.13162
# [173]	train-rmse:4.8005	test-rmse:5.12503
# [174]	train-rmse:4.79652	test-rmse:5.12461
# [175]	train-rmse:4.79181	test-rmse:5.12205
# [176]	train-rmse:4.78634	test-rmse:5.1187
# [177]	train-rmse:4.78441	test-rmse:5.11753
# [178]	train-rmse:4.78148	test-rmse:5.11511
# [179]	train-rmse:4.77788	test-rmse:5.1136
# [180]	train-rmse:4.77408	test-rmse:5.1112
# [181]	train-rmse:4.76902	test-rmse:5.10759
# [182]	train-rmse:4.76376	test-rmse:5.10532
# [183]	train-rmse:4.7597	test-rmse:5.09997
# [184]	train-rmse:4.75638	test-rmse:5.09895
# [185]	train-rmse:4.75209	test-rmse:5.09798
# [186]	train-rmse:4.74971	test-rmse:5.09558
# [187]	train-rmse:4.74762	test-rmse:5.09433
# [188]	train-rmse:4.74689	test-rmse:5.09366
# [189]	train-rmse:4.74493	test-rmse:5.09252
# [190]	train-rmse:4.74321	test-rmse:5.08964
# [191]	train-rmse:4.73597	test-rmse:5.08843
# [192]	train-rmse:4.73381	test-rmse:5.08656
# [193]	train-rmse:4.73046	test-rmse:5.085
# [194]	train-rmse:4.72736	test-rmse:5.08398
# [195]	train-rmse:4.7241	test-rmse:5.08272
# [196]	train-rmse:4.72084	test-rmse:5.07975
# [197]	train-rmse:4.71972	test-rmse:5.0787
# [198]	train-rmse:4.71864	test-rmse:5.07742
# [199]	train-rmse:4.71626	test-rmse:5.07611
# [200]	train-rmse:4.71459	test-rmse:5.0751
# [201]	train-rmse:4.71237	test-rmse:5.07316
# [202]	train-rmse:4.70829	test-rmse:5.07231
# [203]	train-rmse:4.70593	test-rmse:5.07088
# [204]	train-rmse:4.70378	test-rmse:5.06827
# [205]	train-rmse:4.69957	test-rmse:5.06669
# [206]	train-rmse:4.6976	test-rmse:5.06634
# [207]	train-rmse:4.69515	test-rmse:5.06447
# [208]	train-rmse:4.68874	test-rmse:5.06198
# [209]	train-rmse:4.68644	test-rmse:5.06149
# [210]	train-rmse:4.68263	test-rmse:5.05884
# [211]	train-rmse:4.68025	test-rmse:5.05758
# [212]	train-rmse:4.67886	test-rmse:5.05684
# [213]	train-rmse:4.67732	test-rmse:5.05509
# [214]	train-rmse:4.67495	test-rmse:5.05423
# [215]	train-rmse:4.67291	test-rmse:5.05331
# [216]	train-rmse:4.67207	test-rmse:5.05223
# [217]	train-rmse:4.66864	test-rmse:5.05094
# [218]	train-rmse:4.66708	test-rmse:5.04985
# [219]	train-rmse:4.66602	test-rmse:5.04919
# [220]	train-rmse:4.66439	test-rmse:5.04917
# [221]	train-rmse:4.66145	test-rmse:5.04597
# [222]	train-rmse:4.65991	test-rmse:5.04431
# [223]	train-rmse:4.65783	test-rmse:5.04336
# [224]	train-rmse:4.65502	test-rmse:5.04245
# [225]	train-rmse:4.65402	test-rmse:5.0413
# [226]	train-rmse:4.65314	test-rmse:5.04062
# [227]	train-rmse:4.65018	test-rmse:5.03964
# [228]	train-rmse:4.64837	test-rmse:5.03924
# [229]	train-rmse:4.64348	test-rmse:5.03613
# [230]	train-rmse:4.64008	test-rmse:5.03485
# [231]	train-rmse:4.63747	test-rmse:5.03422
# [232]	train-rmse:4.63583	test-rmse:5.03356
# [233]	train-rmse:4.63236	test-rmse:5.03087
# [234]	train-rmse:4.63006	test-rmse:5.03041
# [235]	train-rmse:4.62641	test-rmse:5.02857
# [236]	train-rmse:4.6244	test-rmse:5.02542
# [237]	train-rmse:4.62321	test-rmse:5.02495
# [238]	train-rmse:4.62105	test-rmse:5.02415
# [239]	train-rmse:4.61913	test-rmse:5.02186
# [240]	train-rmse:4.61675	test-rmse:5.01999
# [241]	train-rmse:4.61345	test-rmse:5.01899
# [242]	train-rmse:4.61201	test-rmse:5.01832
# [243]	train-rmse:4.61124	test-rmse:5.01752
# [244]	train-rmse:4.60619	test-rmse:5.01359
# [245]	train-rmse:4.60196	test-rmse:5.01289
# [246]	train-rmse:4.60015	test-rmse:5.01072
# [247]	train-rmse:4.59911	test-rmse:5.00986
# [248]	train-rmse:4.59848	test-rmse:5.00939
# [249]	train-rmse:4.59559	test-rmse:5.00596
# [250]	train-rmse:4.59328	test-rmse:5.00481
# [251]	train-rmse:4.59046	test-rmse:5.00256
# [252]	train-rmse:4.58782	test-rmse:5.00053
# [253]	train-rmse:4.58412	test-rmse:4.9988
# [254]	train-rmse:4.58108	test-rmse:4.99814
# [255]	train-rmse:4.5798	test-rmse:4.99708
# [256]	train-rmse:4.57656	test-rmse:4.99565
# [257]	train-rmse:4.57317	test-rmse:4.99337
# [258]	train-rmse:4.57182	test-rmse:4.99284
# [259]	train-rmse:4.57072	test-rmse:4.99293
# [260]	train-rmse:4.56968	test-rmse:4.99275
# [261]	train-rmse:4.5676	test-rmse:4.991
# [262]	train-rmse:4.56591	test-rmse:4.98897
# [263]	train-rmse:4.56417	test-rmse:4.98843
# [264]	train-rmse:4.5636	test-rmse:4.98805
# [265]	train-rmse:4.56245	test-rmse:4.98769
# [266]	train-rmse:4.55918	test-rmse:4.98609
# [267]	train-rmse:4.55614	test-rmse:4.9865
# [268]	train-rmse:4.55482	test-rmse:4.98587
# [269]	train-rmse:4.55128	test-rmse:4.98654
# [270]	train-rmse:4.55045	test-rmse:4.98579
# [271]	train-rmse:4.54796	test-rmse:4.98411
# [272]	train-rmse:4.54691	test-rmse:4.98326
# [273]	train-rmse:4.54093	test-rmse:4.98144
# [274]	train-rmse:4.53905	test-rmse:4.98066
# [275]	train-rmse:4.53783	test-rmse:4.97996
# [276]	train-rmse:4.533	test-rmse:4.97867
# [277]	train-rmse:4.53188	test-rmse:4.97772
# [278]	train-rmse:4.53062	test-rmse:4.97755
# [279]	train-rmse:4.52958	test-rmse:4.97657
# [280]	train-rmse:4.52807	test-rmse:4.97515
# [281]	train-rmse:4.52733	test-rmse:4.97467
# [282]	train-rmse:4.52549	test-rmse:4.97424
# [283]	train-rmse:4.52074	test-rmse:4.96959
# [284]	train-rmse:4.51778	test-rmse:4.96881
# [285]	train-rmse:4.51494	test-rmse:4.96798
# [286]	train-rmse:4.51333	test-rmse:4.96662
# [287]	train-rmse:4.51258	test-rmse:4.96645
# [288]	train-rmse:4.5108	test-rmse:4.96643
# [289]	train-rmse:4.50661	test-rmse:4.96851
# [290]	train-rmse:4.5044	test-rmse:4.96644
# [291]	train-rmse:4.50291	test-rmse:4.96551
# [292]	train-rmse:4.5004	test-rmse:4.96467
# [293]	train-rmse:4.49864	test-rmse:4.96386
# [294]	train-rmse:4.4962	test-rmse:4.96301
# [295]	train-rmse:4.49385	test-rmse:4.96278
# [296]	train-rmse:4.49091	test-rmse:4.96303
# [297]	train-rmse:4.48876	test-rmse:4.96187
# [298]	train-rmse:4.48724	test-rmse:4.96082
# [299]	train-rmse:4.48531	test-rmse:4.95855
# [300]	train-rmse:4.48385	test-rmse:4.95757
# [301]	train-rmse:4.48049	test-rmse:4.95837
# [302]	train-rmse:4.47965	test-rmse:4.9577
# [303]	train-rmse:4.47806	test-rmse:4.95685
# [304]	train-rmse:4.47646	test-rmse:4.95503
# [305]	train-rmse:4.47526	test-rmse:4.95393
# [306]	train-rmse:4.47311	test-rmse:4.9534
# [307]	train-rmse:4.4725	test-rmse:4.95295
# [308]	train-rmse:4.47159	test-rmse:4.95222
# [309]	train-rmse:4.47086	test-rmse:4.95172
# [310]	train-rmse:4.47004	test-rmse:4.95129
# [311]	train-rmse:4.46601	test-rmse:4.95167
# [312]	train-rmse:4.46274	test-rmse:4.95061
# [313]	train-rmse:4.46116	test-rmse:4.94971
# [314]	train-rmse:4.45897	test-rmse:4.94729
# [315]	train-rmse:4.45625	test-rmse:4.94883
# [316]	train-rmse:4.45311	test-rmse:4.94716
# [317]	train-rmse:4.4507	test-rmse:4.94732
# [318]	train-rmse:4.44979	test-rmse:4.9471
# [319]	train-rmse:4.44724	test-rmse:4.944
# [320]	train-rmse:4.44201	test-rmse:4.94201
# [321]	train-rmse:4.43912	test-rmse:4.94133
# [322]	train-rmse:4.43854	test-rmse:4.94095
# [323]	train-rmse:4.43747	test-rmse:4.9401
# [324]	train-rmse:4.43596	test-rmse:4.9398
# [325]	train-rmse:4.43437	test-rmse:4.93836
# [326]	train-rmse:4.43323	test-rmse:4.93812
# [327]	train-rmse:4.4317	test-rmse:4.9376
# [328]	train-rmse:4.42702	test-rmse:4.93606
# [329]	train-rmse:4.42366	test-rmse:4.93443
# [330]	train-rmse:4.41856	test-rmse:4.9324
# [331]	train-rmse:4.41451	test-rmse:4.93162
# [332]	train-rmse:4.41277	test-rmse:4.93022
# [333]	train-rmse:4.41083	test-rmse:4.92894
# [334]	train-rmse:4.4092	test-rmse:4.9278
# [335]	train-rmse:4.40718	test-rmse:4.92808
# [336]	train-rmse:4.40613	test-rmse:4.92755
# [337]	train-rmse:4.40516	test-rmse:4.92645
# [338]	train-rmse:4.40145	test-rmse:4.92605
# [339]	train-rmse:4.39897	test-rmse:4.92622
# [340]	train-rmse:4.39585	test-rmse:4.92491
# [341]	train-rmse:4.39395	test-rmse:4.92441
# [342]	train-rmse:4.39327	test-rmse:4.92392
# [343]	train-rmse:4.3926	test-rmse:4.92439
# [344]	train-rmse:4.38946	test-rmse:4.92344
# [345]	train-rmse:4.38842	test-rmse:4.92235
# [346]	train-rmse:4.38765	test-rmse:4.92178
# [347]	train-rmse:4.38537	test-rmse:4.92142
# [348]	train-rmse:4.38416	test-rmse:4.92066
# [349]	train-rmse:4.38287	test-rmse:4.92045
# [350]	train-rmse:4.3802	test-rmse:4.92049
# [351]	train-rmse:4.3761	test-rmse:4.91953
# [352]	train-rmse:4.37356	test-rmse:4.91919
# [353]	train-rmse:4.37261	test-rmse:4.91875
# [354]	train-rmse:4.37123	test-rmse:4.91798
# [355]	train-rmse:4.37084	test-rmse:4.91764
# [356]	train-rmse:4.36731	test-rmse:4.91643
# [357]	train-rmse:4.36689	test-rmse:4.91631
# [358]	train-rmse:4.36371	test-rmse:4.91467
# [359]	train-rmse:4.36257	test-rmse:4.91395
# [360]	train-rmse:4.36207	test-rmse:4.9136
# [361]	train-rmse:4.35941	test-rmse:4.91156
# [362]	train-rmse:4.35864	test-rmse:4.91137
# [363]	train-rmse:4.35738	test-rmse:4.91096
# [364]	train-rmse:4.3569	test-rmse:4.91061
# [365]	train-rmse:4.35577	test-rmse:4.91023
# [366]	train-rmse:4.3551	test-rmse:4.90981
# [367]	train-rmse:4.35475	test-rmse:4.90968
# [368]	train-rmse:4.35197	test-rmse:4.90819
# [369]	train-rmse:4.3498	test-rmse:4.90766
# [370]	train-rmse:4.34732	test-rmse:4.90717
# [371]	train-rmse:4.34579	test-rmse:4.90639
# [372]	train-rmse:4.34497	test-rmse:4.90582
# [373]	train-rmse:4.34168	test-rmse:4.90158
# [374]	train-rmse:4.33982	test-rmse:4.90112
# [375]	train-rmse:4.33705	test-rmse:4.89977
# [376]	train-rmse:4.33508	test-rmse:4.89968
# [377]	train-rmse:4.33284	test-rmse:4.89877
# [378]	train-rmse:4.33204	test-rmse:4.89844
# [379]	train-rmse:4.33075	test-rmse:4.89684
# [380]	train-rmse:4.3293	test-rmse:4.8963
# [381]	train-rmse:4.32761	test-rmse:4.89318
# [382]	train-rmse:4.32642	test-rmse:4.89348
# [383]	train-rmse:4.32552	test-rmse:4.89288
# [384]	train-rmse:4.32389	test-rmse:4.89292
# [385]	train-rmse:4.32284	test-rmse:4.89241
# [386]	train-rmse:4.32012	test-rmse:4.89165
# [387]	train-rmse:4.31979	test-rmse:4.89148
# [388]	train-rmse:4.31816	test-rmse:4.89014
# [389]	train-rmse:4.31682	test-rmse:4.88891
# [390]	train-rmse:4.31371	test-rmse:4.8886
# [391]	train-rmse:4.31097	test-rmse:4.88788
# [392]	train-rmse:4.30885	test-rmse:4.8872
# [393]	train-rmse:4.3071	test-rmse:4.88681
# [394]	train-rmse:4.30374	test-rmse:4.88792
# [395]	train-rmse:4.30286	test-rmse:4.88751
# [396]	train-rmse:4.30216	test-rmse:4.88708
# [397]	train-rmse:4.30127	test-rmse:4.88638
# [398]	train-rmse:4.2998	test-rmse:4.88601
# [399]	train-rmse:4.29886	test-rmse:4.88548
# [400]	train-rmse:4.29794	test-rmse:4.88528
# [401]	train-rmse:4.29752	test-rmse:4.88497
# [402]	train-rmse:4.29716	test-rmse:4.88472
# [403]	train-rmse:4.29474	test-rmse:4.88405
# [404]	train-rmse:4.29373	test-rmse:4.88352
# [405]	train-rmse:4.29257	test-rmse:4.88297
# [406]	train-rmse:4.29141	test-rmse:4.88203
# [407]	train-rmse:4.28919	test-rmse:4.88083
# [408]	train-rmse:4.28752	test-rmse:4.8816
# [409]	train-rmse:4.28527	test-rmse:4.87852
# [410]	train-rmse:4.28428	test-rmse:4.87816
# [411]	train-rmse:4.28362	test-rmse:4.87785
# [412]	train-rmse:4.28185	test-rmse:4.87708
# [413]	train-rmse:4.28042	test-rmse:4.87685
# [414]	train-rmse:4.27987	test-rmse:4.87663
# [415]	train-rmse:4.27899	test-rmse:4.87619
# [416]	train-rmse:4.27833	test-rmse:4.87565
# [417]	train-rmse:4.2774	test-rmse:4.87524
# [418]	train-rmse:4.27531	test-rmse:4.87525
# [419]	train-rmse:4.27427	test-rmse:4.87509
# [420]	train-rmse:4.2733	test-rmse:4.87413
# [421]	train-rmse:4.27077	test-rmse:4.87332
# [422]	train-rmse:4.26996	test-rmse:4.87272
# [423]	train-rmse:4.26898	test-rmse:4.87225
# [424]	train-rmse:4.26668	test-rmse:4.8715
# [425]	train-rmse:4.265	test-rmse:4.87123
# [426]	train-rmse:4.26298	test-rmse:4.8703
# [427]	train-rmse:4.26219	test-rmse:4.86998
# [428]	train-rmse:4.26169	test-rmse:4.86946
# [429]	train-rmse:4.26073	test-rmse:4.86889
# [430]	train-rmse:4.25997	test-rmse:4.86849
# [431]	train-rmse:4.25968	test-rmse:4.86824
# [432]	train-rmse:4.25936	test-rmse:4.86801
# [433]	train-rmse:4.25853	test-rmse:4.86706
# [434]	train-rmse:4.25819	test-rmse:4.86687
# [435]	train-rmse:4.25647	test-rmse:4.86645
# [436]	train-rmse:4.25499	test-rmse:4.86624
# [437]	train-rmse:4.25343	test-rmse:4.86582
# [438]	train-rmse:4.25229	test-rmse:4.86551
# [439]	train-rmse:4.25043	test-rmse:4.86508
# [440]	train-rmse:4.24928	test-rmse:4.86684
# [441]	train-rmse:4.24808	test-rmse:4.86637
# [442]	train-rmse:4.24719	test-rmse:4.86526
# [443]	train-rmse:4.2456	test-rmse:4.86498
# [444]	train-rmse:4.24501	test-rmse:4.86464
# [445]	train-rmse:4.24189	test-rmse:4.86356
# [446]	train-rmse:4.23883	test-rmse:4.86298
# [447]	train-rmse:4.23766	test-rmse:4.86344
# [448]	train-rmse:4.23442	test-rmse:4.86447
# [449]	train-rmse:4.23268	test-rmse:4.86436
# [450]	train-rmse:4.23131	test-rmse:4.86383
# [451]	train-rmse:4.23021	test-rmse:4.86329

# %%
model_1
# Out:
#      train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0           7.993683        0.173063        7.967547       0.716690
# 1           7.676595        0.164397        7.655071       0.707542
# 2           7.407930        0.157907        7.391842       0.697180
# 3           7.181811        0.151891        7.172567       0.683760
# 4           6.982813        0.148613        6.985764       0.661336
# 5           6.822337        0.146630        6.826675       0.649484
# 6           6.689696        0.141505        6.699616       0.640954
# 7           6.579756        0.141152        6.599768       0.631106
# 8           6.483219        0.133613        6.510103       0.624256
# 9           6.398223        0.132193        6.431563       0.616674
# 10          6.325069        0.138835        6.365052       0.604745
# 11          6.266377        0.131112        6.313003       0.605831
# 12          6.202369        0.132958        6.257617       0.600557
# 13          6.151639        0.129824        6.216035       0.598435
# 14          6.109765        0.127441        6.180311       0.595575
# 15          6.072271        0.126831        6.147507       0.588196
# 16          6.029413        0.125384        6.113037       0.583431
# 17          5.995828        0.127727        6.082688       0.574640
# 18          5.971537        0.125557        6.061651       0.570785
# 19          5.933221        0.128199        6.029323       0.568547
# 20          5.900954        0.123594        5.996998       0.565765
# 21          5.872284        0.130786        5.973396       0.555949
# 22          5.827933        0.116632        5.936024       0.569085
# 23          5.795785        0.115580        5.912738       0.566436
# 24          5.760900        0.111389        5.885220       0.563796
# 25          5.733443        0.108872        5.862741       0.568284
# 26          5.709249        0.109635        5.843967       0.564116
# 27          5.679783        0.108632        5.820165       0.562204
# 28          5.653050        0.110910        5.793078       0.554336
# 29          5.635989        0.107550        5.781508       0.554239
# ..               ...             ...             ...            ...
# 417         4.277398        0.069753        4.875235       0.512367
# 418         4.275314        0.070200        4.875254       0.512686
# 419         4.274267        0.070040        4.875093       0.512662
# 420         4.273297        0.069707        4.874131       0.513248
# 421         4.270771        0.070656        4.873317       0.512824
# 422         4.269962        0.070729        4.872718       0.512660
# 423         4.268979        0.071224        4.872247       0.512539
# 424         4.266682        0.072041        4.871504       0.512272
# 425         4.264995        0.073128        4.871228       0.512494
# 426         4.262976        0.073038        4.870296       0.512685
# 427         4.262189        0.073076        4.869981       0.512766
# 428         4.261695        0.073127        4.869456       0.512567
# 429         4.260726        0.072632        4.868891       0.513282
# 430         4.259965        0.072881        4.868490       0.513164
# 431         4.259683        0.072902        4.868245       0.513174
# 432         4.259359        0.072671        4.868006       0.513462
# 433         4.258526        0.072382        4.867058       0.514230
# 434         4.258189        0.072281        4.866872       0.514291
# 435         4.256465        0.072721        4.866454       0.514412
# 436         4.254988        0.072990        4.866236       0.514577
# 437         4.253426        0.072808        4.865818       0.514817
# 438         4.252288        0.072420        4.865509       0.514985
# 439         4.250428        0.072571        4.865076       0.515286
# 440         4.249275        0.073258        4.866844       0.516004
# 441         4.248080        0.074016        4.866372       0.515891
# 442         4.247191        0.073710        4.865258       0.516402
# 443         4.245604        0.073355        4.864982       0.516372
# 444         4.245010        0.073394        4.864637       0.516306
# 445         4.241892        0.074331        4.863563       0.516159
# 446         4.238827        0.073650        4.862981       0.517043
#
# [447 rows x 4 columns]

# %%
model_2 = xgb.train(params=xgb_params,
                    dtrain=xgb_train_data,
                    num_boost_round=1000)

# %%
model_2

# %%
validation_predictions = model_2.predict(xgb_validation_data)

# %%
np.sqrt(mean_squared_error(np.clip(validation_predictions, 0 , 20),  np.clip(new_Y, 0, 20)))
# Out:
# 2.2703912594568307

# %% [markdown]
# ##### That looks like a reasonably good jump !!! I am not sure what else we can do with xgboost on the raw features alone (we can create other features and then apply xgboost on the same, and we will do it later in a separate notebook).
