# %% [markdown]
# ### Summary
#
# Build a model using xgboost and verify it's performance on the validation set.

# %%
import pandas as pd
import xgboost as xgb
import numpy as np
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ##### Get relevant data in monthly form

# %%
sales_train = pd.read_csv('input/sales_train.csv')

# %%
monthly_sales_data = sales_train[['date_block_num', 'shop_id', 'item_id', 'item_cnt_day']].groupby(
    ['date_block_num', 'shop_id', 'item_id']).sum()
monthly_sales_data.rename(columns={'item_cnt_day':'item_cnt_month'}, inplace=True)
monthly_sales_data.reset_index(['date_block_num', 'shop_id', 'item_id'], inplace=True)

# %%
monthly_sales_data.columns
# Out:
# Index(['date_block_num', 'shop_id', 'item_id', 'item_cnt_month'], dtype='object')

# %%
items = pd.read_csv('input/items.csv')

# %%
items.columns
# Out:
# Index(['item_name', 'item_id', 'item_category_id'], dtype='object')

# %%
item_id_to_item_category_id = dict(zip(items.item_id, items.item_category_id))

# %%
monthly_sales_data['item_category_id'] = monthly_sales_data['item_id'].apply(lambda x : item_id_to_item_category_id.get(x, -1))

# %%
train_data = monthly_sales_data[monthly_sales_data.date_block_num != 32]
validation_data = monthly_sales_data[monthly_sales_data.date_block_num == 32]

# %% [markdown]
# ##### Get started with xgboost.

# %%
Y_COLUMN = 'item_cnt_month'
X_COLUMNS = [col for col in monthly_sales_data.columns if col != Y_COLUMN]

# %%
Y = train_data[[Y_COLUMN]]
X = train_data[X_COLUMNS]

# %%
xgb_train_data = xgb.DMatrix(X, Y, feature_names=X_COLUMNS)

# %%
xgb_params = {'eta' : 0.1}

# %%
model_1 = xgb.train(params=xgb_params,
                    dtrain=xgb_train_data,
                    num_boost_round=100)

# %%
model_1

# %%
new_X = validation_data[X_COLUMNS]
new_Y = validation_data[[Y_COLUMN]]

# %%
xgb_validation_data = xgb.DMatrix(new_X, feature_names=X_COLUMNS)

# %%
validation_predictions = model_1.predict(xgb_validation_data)

# %%
np.sqrt(mean_squared_error(np.clip(validation_predictions, 0 , 20),  np.clip(new_Y, 0, 20)))
# Out:
# 2.2702181217098234

# %% [markdown]
# ##### That looks encouraging. This is the best of what we have seen so far. Let us try training the model a bit further.

# %%
xgb_params = {'eta' : 0.01}

# %%
model_1 = xgb.train(params=xgb_params,
                    dtrain=xgb_train_data,
                    num_boost_round=1000)

# %%
validation_predictions = model_1.predict(xgb_validation_data)

# %%
np.sqrt(mean_squared_error(np.clip(validation_predictions, 0 , 20),  np.clip(new_Y, 0, 20)))
# Out:
# 2.2645925539553553

# %% [markdown]
# ##### Okay that looks to be showing diminishing returns and let us see early stopping would help us. Note, however that because of clipping, this may not offer us the best solution, but should be reasonably close. Let us go on !

# %%
xgb_validation_data = xgb.DMatrix(new_X, new_Y, feature_names=X_COLUMNS)

# %%
xgb_params = {'eta' : 0.01, 'eval_metric' : 'rmse'}

# %%
model_1 = xgb.train(params=xgb_params,
                    dtrain=xgb_train_data,
                    num_boost_round=1000,
                    evals=[(xgb_validation_data, 'eval')],
                    early_stopping_rounds=5)
# Out:
# [0]	eval-rmse:18.5337
# Will train until eval-rmse hasn't improved in 5 rounds.
# [1]	eval-rmse:18.5178
# [2]	eval-rmse:18.5029
# [3]	eval-rmse:18.4878
# [4]	eval-rmse:18.4735
# [5]	eval-rmse:18.4591
# [6]	eval-rmse:18.4455
# [7]	eval-rmse:18.4319
# [8]	eval-rmse:18.4185
# [9]	eval-rmse:18.4061
# [10]	eval-rmse:18.3934
# [11]	eval-rmse:18.3809
# [12]	eval-rmse:18.3693
# [13]	eval-rmse:18.3574
# [14]	eval-rmse:18.3459
# [15]	eval-rmse:18.3345
# [16]	eval-rmse:18.3258
# [17]	eval-rmse:18.3155
# [18]	eval-rmse:18.3072
# [19]	eval-rmse:18.2991
# [20]	eval-rmse:18.2895
# [21]	eval-rmse:18.2817
# [22]	eval-rmse:18.272
# [23]	eval-rmse:18.2645
# [24]	eval-rmse:18.2554
# [25]	eval-rmse:18.2488
# [26]	eval-rmse:18.24
# [27]	eval-rmse:18.2334
# [28]	eval-rmse:18.2249
# [29]	eval-rmse:18.2185
# [30]	eval-rmse:18.2094
# [31]	eval-rmse:18.2025
# [32]	eval-rmse:18.1956
# [33]	eval-rmse:18.188
# [34]	eval-rmse:18.1812
# [35]	eval-rmse:18.1737
# [36]	eval-rmse:18.1673
# [37]	eval-rmse:18.16
# [38]	eval-rmse:18.1537
# [39]	eval-rmse:18.147
# [40]	eval-rmse:18.1413
# [41]	eval-rmse:18.1345
# [42]	eval-rmse:18.1297
# [43]	eval-rmse:18.1252
# [44]	eval-rmse:18.1189
# [45]	eval-rmse:18.1146
# [46]	eval-rmse:18.1101
# [47]	eval-rmse:18.1046
# [48]	eval-rmse:18.1004
# [49]	eval-rmse:18.0964
# [50]	eval-rmse:18.0909
# [51]	eval-rmse:18.0872
# [52]	eval-rmse:18.0831
# [53]	eval-rmse:18.0794
# [54]	eval-rmse:18.074
# [55]	eval-rmse:18.0705
# [56]	eval-rmse:18.0667
# [57]	eval-rmse:18.0632
# [58]	eval-rmse:18.0599
# [59]	eval-rmse:18.0564
# [60]	eval-rmse:18.053
# [61]	eval-rmse:18.048
# [62]	eval-rmse:18.0448
# [63]	eval-rmse:18.0416
# [64]	eval-rmse:18.0384
# [65]	eval-rmse:18.0352
# [66]	eval-rmse:18.0322
# [67]	eval-rmse:18.0277
# [68]	eval-rmse:18.0247
# [69]	eval-rmse:18.0217
# [70]	eval-rmse:18.019
# [71]	eval-rmse:18.0161
# [72]	eval-rmse:18.0119
# [73]	eval-rmse:18.0092
# [74]	eval-rmse:18.0065
# [75]	eval-rmse:18.0028
# [76]	eval-rmse:18.0002
# [77]	eval-rmse:17.9977
# [78]	eval-rmse:17.9954
# [79]	eval-rmse:17.9899
# [80]	eval-rmse:17.9874
# [81]	eval-rmse:17.9834
# [82]	eval-rmse:17.9811
# [83]	eval-rmse:17.9771
# [84]	eval-rmse:17.9749
# [85]	eval-rmse:17.9698
# [86]	eval-rmse:17.9676
# [87]	eval-rmse:17.9638
# [88]	eval-rmse:17.9617
# [89]	eval-rmse:17.9581
# [90]	eval-rmse:17.9549
# [91]	eval-rmse:17.9501
# [92]	eval-rmse:17.9481
# [93]	eval-rmse:17.9435
# [94]	eval-rmse:17.939
# [95]	eval-rmse:17.9358
# [96]	eval-rmse:17.934
# [97]	eval-rmse:17.9296
# [98]	eval-rmse:17.9276
# [99]	eval-rmse:17.9233
# [100]	eval-rmse:17.9203
# [101]	eval-rmse:17.9161
# [102]	eval-rmse:17.9142
# [103]	eval-rmse:17.9123
# [104]	eval-rmse:17.9106
# [105]	eval-rmse:17.9068
# [106]	eval-rmse:17.9039
# [107]	eval-rmse:17.9007
# [108]	eval-rmse:17.8995
# [109]	eval-rmse:17.8967
# [110]	eval-rmse:17.8934
# [111]	eval-rmse:17.892
# [112]	eval-rmse:17.8872
# [113]	eval-rmse:17.8862
# [114]	eval-rmse:17.8848
# [115]	eval-rmse:17.8822
# [116]	eval-rmse:17.8787
# [117]	eval-rmse:17.8763
# [118]	eval-rmse:17.8733
# [119]	eval-rmse:17.8724
# [120]	eval-rmse:17.8681
# [121]	eval-rmse:17.8672
# [122]	eval-rmse:17.8648
# [123]	eval-rmse:17.8641
# [124]	eval-rmse:17.8602
# [125]	eval-rmse:17.8592
# [126]	eval-rmse:17.8555
# [127]	eval-rmse:17.8547
# [128]	eval-rmse:17.8539
# [129]	eval-rmse:17.8504
# [130]	eval-rmse:17.8495
# [131]	eval-rmse:17.8488
# [132]	eval-rmse:17.8453
# [133]	eval-rmse:17.8444
# [134]	eval-rmse:17.8427
# [135]	eval-rmse:17.8413
# [136]	eval-rmse:17.8388
# [137]	eval-rmse:17.8382
# [138]	eval-rmse:17.835
# [139]	eval-rmse:17.8341
# [140]	eval-rmse:17.8333
# [141]	eval-rmse:17.8317
# [142]	eval-rmse:17.8291
# [143]	eval-rmse:17.8276
# [144]	eval-rmse:17.8246
# [145]	eval-rmse:17.8232
# [146]	eval-rmse:17.8225
# [147]	eval-rmse:17.8211
# [148]	eval-rmse:17.8182
# [149]	eval-rmse:17.8176
# [150]	eval-rmse:17.8147
# [151]	eval-rmse:17.8133
# [152]	eval-rmse:17.8121
# [153]	eval-rmse:17.8101
# [154]	eval-rmse:17.8074
# [155]	eval-rmse:17.806
# [156]	eval-rmse:17.8054
# [157]	eval-rmse:17.804
# [158]	eval-rmse:17.8019
# [159]	eval-rmse:17.8015
# [160]	eval-rmse:17.8002
# [161]	eval-rmse:17.7981
# [162]	eval-rmse:17.7969
# [163]	eval-rmse:17.7964
# [164]	eval-rmse:17.7959
# [165]	eval-rmse:17.7947
# [166]	eval-rmse:17.7923
# [167]	eval-rmse:17.7919
# [168]	eval-rmse:17.7915
# [169]	eval-rmse:17.7906
# [170]	eval-rmse:17.7883
# [171]	eval-rmse:17.7866
# [172]	eval-rmse:17.7848
# [173]	eval-rmse:17.7831
# [174]	eval-rmse:17.7819
# [175]	eval-rmse:17.7815
# [176]	eval-rmse:17.7799
# [177]	eval-rmse:17.7794
# [178]	eval-rmse:17.7785
# [179]	eval-rmse:17.7775
# [180]	eval-rmse:17.7763
# [181]	eval-rmse:17.7754
# [182]	eval-rmse:17.7749
# [183]	eval-rmse:17.774
# [184]	eval-rmse:17.7722
# [185]	eval-rmse:17.7713
# [186]	eval-rmse:17.7695
# [187]	eval-rmse:17.7692
# [188]	eval-rmse:17.7689
# [189]	eval-rmse:17.7677
# [190]	eval-rmse:17.7655
# [191]	eval-rmse:17.7651
# [192]	eval-rmse:17.7644
# [193]	eval-rmse:17.7628
# [194]	eval-rmse:17.7624
# [195]	eval-rmse:17.7621
# [196]	eval-rmse:17.7614
# [197]	eval-rmse:17.7604
# [198]	eval-rmse:17.7601
# [199]	eval-rmse:17.7585
# [200]	eval-rmse:17.7576
# [201]	eval-rmse:17.7567
# [202]	eval-rmse:17.7558
# [203]	eval-rmse:17.7552
# [204]	eval-rmse:17.7536
# [205]	eval-rmse:17.7528
# [206]	eval-rmse:17.7512
# [207]	eval-rmse:17.75
# [208]	eval-rmse:17.7496
# [209]	eval-rmse:17.7478
# [210]	eval-rmse:17.7475
# [211]	eval-rmse:17.7471
# [212]	eval-rmse:17.7459
# [213]	eval-rmse:17.7443
# [214]	eval-rmse:17.7432
# [215]	eval-rmse:17.7416
# [216]	eval-rmse:17.7405
# [217]	eval-rmse:17.7403
# [218]	eval-rmse:17.7392
# [219]	eval-rmse:17.7378
# [220]	eval-rmse:17.7364
# [221]	eval-rmse:17.7362
# [222]	eval-rmse:17.7354
# [223]	eval-rmse:17.7339
# [224]	eval-rmse:17.7301
# [225]	eval-rmse:17.73
# [226]	eval-rmse:17.7267
# [227]	eval-rmse:17.7262
# [228]	eval-rmse:17.7253
# [229]	eval-rmse:17.7246
# [230]	eval-rmse:17.7242
# [231]	eval-rmse:17.7211
# [232]	eval-rmse:17.7206
# [233]	eval-rmse:17.7202
# [234]	eval-rmse:17.7198
# [235]	eval-rmse:17.7165
# [236]	eval-rmse:17.7164
# [237]	eval-rmse:17.716
# [238]	eval-rmse:17.7156
# [239]	eval-rmse:17.7152
# [240]	eval-rmse:17.7151
# [241]	eval-rmse:17.7147
# [242]	eval-rmse:17.7143
# [243]	eval-rmse:17.7109
# [244]	eval-rmse:17.7094
# [245]	eval-rmse:17.709
# [246]	eval-rmse:17.7058
# [247]	eval-rmse:17.7055
# [248]	eval-rmse:17.7023
# [249]	eval-rmse:17.7019
# [250]	eval-rmse:17.6982
# [251]	eval-rmse:17.6897
# [252]	eval-rmse:17.6893
# [253]	eval-rmse:17.6809
# [254]	eval-rmse:17.6801
# [255]	eval-rmse:17.6719
# [256]	eval-rmse:17.6715
# [257]	eval-rmse:17.6634
# [258]	eval-rmse:17.6626
# [259]	eval-rmse:17.6623
# [260]	eval-rmse:17.662
# [261]	eval-rmse:17.6617
# [262]	eval-rmse:17.6609
# [263]	eval-rmse:17.6605
# [264]	eval-rmse:17.6597
# [265]	eval-rmse:17.6581
# [266]	eval-rmse:17.6578
# [267]	eval-rmse:17.6574
# [268]	eval-rmse:17.6567
# [269]	eval-rmse:17.655
# [270]	eval-rmse:17.6547
# [271]	eval-rmse:17.6531
# [272]	eval-rmse:17.6525
# [273]	eval-rmse:17.6518
# [274]	eval-rmse:17.6326
# [275]	eval-rmse:17.6323
# [276]	eval-rmse:17.6308
# [277]	eval-rmse:17.6275
# [278]	eval-rmse:17.6268
# [279]	eval-rmse:17.608
# [280]	eval-rmse:17.6078
# [281]	eval-rmse:17.5892
# [282]	eval-rmse:17.584
# [283]	eval-rmse:17.5826
# [284]	eval-rmse:17.5819
# [285]	eval-rmse:17.5769
# [286]	eval-rmse:17.5755
# [287]	eval-rmse:17.5706
# [288]	eval-rmse:17.553
# [289]	eval-rmse:17.5524
# [290]	eval-rmse:17.5477
# [291]	eval-rmse:17.5463
# [292]	eval-rmse:17.546
# [293]	eval-rmse:17.5414
# [294]	eval-rmse:17.5412
# [295]	eval-rmse:17.5379
# [296]	eval-rmse:17.5335
# [297]	eval-rmse:17.5332
# [298]	eval-rmse:17.5326
# [299]	eval-rmse:17.5283
# [300]	eval-rmse:17.528
# [301]	eval-rmse:17.5277
# [302]	eval-rmse:17.5265
# [303]	eval-rmse:17.5224
# [304]	eval-rmse:17.5223
# [305]	eval-rmse:17.5217
# [306]	eval-rmse:17.5178
# [307]	eval-rmse:17.5173
# [308]	eval-rmse:17.5173
# [309]	eval-rmse:17.5167
# [310]	eval-rmse:17.5128
# [311]	eval-rmse:17.5127
# [312]	eval-rmse:17.509
# [313]	eval-rmse:17.5086
# [314]	eval-rmse:17.5084
# [315]	eval-rmse:17.5084
# [316]	eval-rmse:17.5048
# [317]	eval-rmse:17.5048
# [318]	eval-rmse:17.5042
# [319]	eval-rmse:17.5008
# [320]	eval-rmse:17.5008
# [321]	eval-rmse:17.4974
# [322]	eval-rmse:17.4971
# [323]	eval-rmse:17.4971
# [324]	eval-rmse:17.4969
# [325]	eval-rmse:17.4937
# [326]	eval-rmse:17.4932
# [327]	eval-rmse:17.4901
# [328]	eval-rmse:17.4896
# [329]	eval-rmse:17.4891
# [330]	eval-rmse:17.4889
# [331]	eval-rmse:17.4883
# [332]	eval-rmse:17.4867
# [333]	eval-rmse:17.4867
# [334]	eval-rmse:17.4851
# [335]	eval-rmse:17.4849
# [336]	eval-rmse:17.4845
# [337]	eval-rmse:17.4831
# [338]	eval-rmse:17.4826
# [339]	eval-rmse:17.4821
# [340]	eval-rmse:17.4817
# [341]	eval-rmse:17.4789
# [342]	eval-rmse:17.4787
# [343]	eval-rmse:17.4775
# [344]	eval-rmse:17.4767
# [345]	eval-rmse:17.4764
# [346]	eval-rmse:17.4759
# [347]	eval-rmse:17.4747
# [348]	eval-rmse:17.4749
# [349]	eval-rmse:17.4747
# [350]	eval-rmse:17.4745
# [351]	eval-rmse:17.4745
# [352]	eval-rmse:17.4735
# [353]	eval-rmse:17.473
# [354]	eval-rmse:17.4723
# [355]	eval-rmse:17.4701
# [356]	eval-rmse:17.4704
# [357]	eval-rmse:17.4714
# [358]	eval-rmse:17.4721
# [359]	eval-rmse:17.4718
# [360]	eval-rmse:17.4696
# [361]	eval-rmse:17.4703
# [362]	eval-rmse:17.4697
# [363]	eval-rmse:17.4706
# [364]	eval-rmse:17.47
# [365]	eval-rmse:17.4698
# Stopping. Best iteration:
# [360]	eval-rmse:17.4696

# %%
validation_predictions = model_1.predict(xgb_validation_data, ntree_limit=model_1.best_ntree_limit)

# %%
np.sqrt(mean_squared_error(np.clip(validation_predictions, 0, 20), np.clip(new_Y, 0, 20)))
# Out:
# 2.296194608869891

# %% [markdown]
# ##### Okay , that does not look to give us something now, but let us check the variable importance here.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1, figsize=(16, 9))
xgb.plot_importance(model_1, ax=ax)

# %% [markdown]
# ##### Let us try if cross validation helps us here. One may question the use of cross validation, since we are dealing with time series data, but we are not exactly treating this as a time series problem, but rather as a modelling problem with item_cnt_month and other parameters.

# %%
Y = train_data[[Y_COLUMN]]
X = train_data[X_COLUMNS]

# %%
xgb_train_data = xgb.DMatrix(X, Y, feature_names=X_COLUMNS)

# %%
xgb_params = {'eta' : 0.1, 'eval_metric' : 'rmse'}

# %%
model_1 = xgb.cv(params=xgb_params,
                 dtrain=xgb_train_data,
                 num_boost_round=1000,
                 nfold=5,
                 early_stopping_rounds=5,
                 callbacks=[xgb.callback.print_evaluation(show_stdv=False)])
# Out:
# [0]	train-rmse:8.17519	test-rmse:8.13578
# [1]	train-rmse:7.8668	test-rmse:7.83215
# [2]	train-rmse:7.60899	test-rmse:7.58025
# [3]	train-rmse:7.39351	test-rmse:7.37076
# [4]	train-rmse:7.20926	test-rmse:7.18789
# [5]	train-rmse:7.05832	test-rmse:7.04036
# [6]	train-rmse:6.93321	test-rmse:6.92575
# [7]	train-rmse:6.82464	test-rmse:6.82752
# [8]	train-rmse:6.72335	test-rmse:6.74105
# [9]	train-rmse:6.64122	test-rmse:6.66217
# [10]	train-rmse:6.5737	test-rmse:6.60178
# [11]	train-rmse:6.49989	test-rmse:6.5383
# [12]	train-rmse:6.438	test-rmse:6.48861
# [13]	train-rmse:6.38363	test-rmse:6.44636
# [14]	train-rmse:6.33694	test-rmse:6.40712
# [15]	train-rmse:6.29158	test-rmse:6.36382
# [16]	train-rmse:6.24971	test-rmse:6.33297
# [17]	train-rmse:6.21501	test-rmse:6.29893
# [18]	train-rmse:6.18745	test-rmse:6.27834
# [19]	train-rmse:6.15075	test-rmse:6.25137
# [20]	train-rmse:6.11848	test-rmse:6.22223
# [21]	train-rmse:6.07578	test-rmse:6.18334
# [22]	train-rmse:6.02687	test-rmse:6.14345
# [23]	train-rmse:5.9973	test-rmse:6.11946
# [24]	train-rmse:5.97489	test-rmse:6.10375
# [25]	train-rmse:5.9457	test-rmse:6.07842
# [26]	train-rmse:5.91978	test-rmse:6.05738
# [27]	train-rmse:5.89564	test-rmse:6.04179
# [28]	train-rmse:5.87057	test-rmse:6.02583
# [29]	train-rmse:5.84944	test-rmse:6.00435
# [30]	train-rmse:5.83037	test-rmse:5.99397
# [31]	train-rmse:5.81278	test-rmse:5.98248
# [32]	train-rmse:5.79752	test-rmse:5.97531
# [33]	train-rmse:5.77804	test-rmse:5.95777
# [34]	train-rmse:5.75248	test-rmse:5.93577
# [35]	train-rmse:5.73487	test-rmse:5.92604
# [36]	train-rmse:5.71303	test-rmse:5.91451
# [37]	train-rmse:5.6988	test-rmse:5.90487
# [38]	train-rmse:5.67951	test-rmse:5.89558
# [39]	train-rmse:5.66967	test-rmse:5.88673
# [40]	train-rmse:5.65721	test-rmse:5.88024
# [41]	train-rmse:5.64307	test-rmse:5.86844
# [42]	train-rmse:5.63214	test-rmse:5.8584
# [43]	train-rmse:5.61879	test-rmse:5.85301
# [44]	train-rmse:5.60777	test-rmse:5.84767
# [45]	train-rmse:5.59469	test-rmse:5.83915
# [46]	train-rmse:5.58632	test-rmse:5.83253
# [47]	train-rmse:5.56499	test-rmse:5.82792
# [48]	train-rmse:5.55818	test-rmse:5.82386
# [49]	train-rmse:5.54916	test-rmse:5.81789
# [50]	train-rmse:5.53865	test-rmse:5.81442
# [51]	train-rmse:5.52775	test-rmse:5.8092
# [52]	train-rmse:5.5231	test-rmse:5.80639
# [53]	train-rmse:5.51339	test-rmse:5.80062
# [54]	train-rmse:5.49678	test-rmse:5.79175
# [55]	train-rmse:5.48658	test-rmse:5.78048
# [56]	train-rmse:5.47555	test-rmse:5.77503
# [57]	train-rmse:5.46903	test-rmse:5.77282
# [58]	train-rmse:5.4619	test-rmse:5.76676
# [59]	train-rmse:5.45294	test-rmse:5.75862
# [60]	train-rmse:5.44776	test-rmse:5.75596
# [61]	train-rmse:5.44205	test-rmse:5.74993
# [62]	train-rmse:5.43187	test-rmse:5.74567
# [63]	train-rmse:5.42614	test-rmse:5.74319
# [64]	train-rmse:5.41877	test-rmse:5.7359
# [65]	train-rmse:5.41257	test-rmse:5.72852
# [66]	train-rmse:5.4063	test-rmse:5.72376
# [67]	train-rmse:5.39357	test-rmse:5.71578
# [68]	train-rmse:5.38899	test-rmse:5.71223
# [69]	train-rmse:5.3846	test-rmse:5.70866
# [70]	train-rmse:5.37602	test-rmse:5.70272
# [71]	train-rmse:5.36799	test-rmse:5.70007
# [72]	train-rmse:5.35958	test-rmse:5.69512
# [73]	train-rmse:5.35658	test-rmse:5.69396
# [74]	train-rmse:5.34869	test-rmse:5.68452
# [75]	train-rmse:5.34129	test-rmse:5.67916
# [76]	train-rmse:5.33434	test-rmse:5.67027
# [77]	train-rmse:5.32684	test-rmse:5.66377
# [78]	train-rmse:5.32186	test-rmse:5.65815
# [79]	train-rmse:5.31024	test-rmse:5.65275
# [80]	train-rmse:5.30556	test-rmse:5.64963
# [81]	train-rmse:5.30006	test-rmse:5.6451
# [82]	train-rmse:5.28969	test-rmse:5.63823
# [83]	train-rmse:5.28527	test-rmse:5.63534
# [84]	train-rmse:5.27889	test-rmse:5.63516
# [85]	train-rmse:5.27269	test-rmse:5.62961
# [86]	train-rmse:5.2688	test-rmse:5.62673
# [87]	train-rmse:5.26365	test-rmse:5.62236
# [88]	train-rmse:5.25681	test-rmse:5.61906
# [89]	train-rmse:5.24979	test-rmse:5.61325
# [90]	train-rmse:5.24096	test-rmse:5.60904
# [91]	train-rmse:5.23532	test-rmse:5.60728
# [92]	train-rmse:5.2295	test-rmse:5.6033
# [93]	train-rmse:5.22478	test-rmse:5.60043
# [94]	train-rmse:5.21886	test-rmse:5.59507
# [95]	train-rmse:5.21399	test-rmse:5.59129
# [96]	train-rmse:5.20933	test-rmse:5.58815
# [97]	train-rmse:5.20279	test-rmse:5.58391
# [98]	train-rmse:5.19753	test-rmse:5.57712
# [99]	train-rmse:5.19111	test-rmse:5.57209
# [100]	train-rmse:5.18791	test-rmse:5.56959
# [101]	train-rmse:5.17883	test-rmse:5.56382
# [102]	train-rmse:5.17371	test-rmse:5.56093
# [103]	train-rmse:5.16915	test-rmse:5.55788
# [104]	train-rmse:5.16727	test-rmse:5.5561
# [105]	train-rmse:5.16519	test-rmse:5.55479
# [106]	train-rmse:5.16022	test-rmse:5.55147
# [107]	train-rmse:5.15596	test-rmse:5.55064
# [108]	train-rmse:5.14913	test-rmse:5.54598
# [109]	train-rmse:5.14507	test-rmse:5.54378
# [110]	train-rmse:5.13557	test-rmse:5.54287
# [111]	train-rmse:5.12911	test-rmse:5.54158
# [112]	train-rmse:5.12649	test-rmse:5.53836
# [113]	train-rmse:5.12242	test-rmse:5.53587
# [114]	train-rmse:5.11827	test-rmse:5.52959
# [115]	train-rmse:5.11019	test-rmse:5.52741
# [116]	train-rmse:5.10379	test-rmse:5.52473
# [117]	train-rmse:5.09523	test-rmse:5.51828
# [118]	train-rmse:5.09369	test-rmse:5.51603
# [119]	train-rmse:5.09136	test-rmse:5.51448
# [120]	train-rmse:5.08212	test-rmse:5.51207
# [121]	train-rmse:5.07826	test-rmse:5.50655
# [122]	train-rmse:5.07613	test-rmse:5.50515
# [123]	train-rmse:5.06992	test-rmse:5.50214
# [124]	train-rmse:5.06634	test-rmse:5.50152
# [125]	train-rmse:5.0635	test-rmse:5.49935
# [126]	train-rmse:5.06063	test-rmse:5.49705
# [127]	train-rmse:5.0491	test-rmse:5.48927
# [128]	train-rmse:5.0463	test-rmse:5.48688
# [129]	train-rmse:5.0432	test-rmse:5.48374
# [130]	train-rmse:5.03906	test-rmse:5.48272
# [131]	train-rmse:5.03575	test-rmse:5.48089
# [132]	train-rmse:5.03239	test-rmse:5.47861
# [133]	train-rmse:5.02908	test-rmse:5.47576
# [134]	train-rmse:5.02466	test-rmse:5.47442
# [135]	train-rmse:5.01967	test-rmse:5.47059
# [136]	train-rmse:5.01625	test-rmse:5.46927
# [137]	train-rmse:5.01357	test-rmse:5.46763
# [138]	train-rmse:5.00875	test-rmse:5.46585
# [139]	train-rmse:5.00564	test-rmse:5.46417
# [140]	train-rmse:5.00286	test-rmse:5.46314
# [141]	train-rmse:5.00048	test-rmse:5.46162
# [142]	train-rmse:4.99641	test-rmse:5.45467
# [143]	train-rmse:4.99143	test-rmse:5.45133
# [144]	train-rmse:4.98741	test-rmse:5.45055
# [145]	train-rmse:4.97968	test-rmse:5.44682
# [146]	train-rmse:4.9765	test-rmse:5.4447
# [147]	train-rmse:4.97317	test-rmse:5.44018
# [148]	train-rmse:4.96539	test-rmse:5.43761
# [149]	train-rmse:4.96154	test-rmse:5.43603
# [150]	train-rmse:4.95388	test-rmse:5.43441
# [151]	train-rmse:4.94922	test-rmse:5.4302
# [152]	train-rmse:4.94491	test-rmse:5.42743
# [153]	train-rmse:4.93955	test-rmse:5.42583
# [154]	train-rmse:4.93765	test-rmse:5.42462
# [155]	train-rmse:4.93279	test-rmse:5.42295
# [156]	train-rmse:4.931	test-rmse:5.42123
# [157]	train-rmse:4.92425	test-rmse:5.41975
# [158]	train-rmse:4.92162	test-rmse:5.41748
# [159]	train-rmse:4.9199	test-rmse:5.41653
# [160]	train-rmse:4.91744	test-rmse:5.41495
# [161]	train-rmse:4.91449	test-rmse:5.41265
# [162]	train-rmse:4.9029	test-rmse:5.40848
# [163]	train-rmse:4.8965	test-rmse:5.40501
# [164]	train-rmse:4.8921	test-rmse:5.40453
# [165]	train-rmse:4.89134	test-rmse:5.40373
# [166]	train-rmse:4.88848	test-rmse:5.40154
# [167]	train-rmse:4.88203	test-rmse:5.39784
# [168]	train-rmse:4.87602	test-rmse:5.3974
# [169]	train-rmse:4.8741	test-rmse:5.39616
# [170]	train-rmse:4.87206	test-rmse:5.39464
# [171]	train-rmse:4.87079	test-rmse:5.39329
# [172]	train-rmse:4.86763	test-rmse:5.39154
# [173]	train-rmse:4.8661	test-rmse:5.39076
# [174]	train-rmse:4.86368	test-rmse:5.38928
# [175]	train-rmse:4.86188	test-rmse:5.38966
# [176]	train-rmse:4.85878	test-rmse:5.38813
# [177]	train-rmse:4.85502	test-rmse:5.38552
# [178]	train-rmse:4.85185	test-rmse:5.38211
# [179]	train-rmse:4.84795	test-rmse:5.38052
# [180]	train-rmse:4.8464	test-rmse:5.37921
# [181]	train-rmse:4.84256	test-rmse:5.37626
# [182]	train-rmse:4.835	test-rmse:5.3727
# [183]	train-rmse:4.83219	test-rmse:5.36882
# [184]	train-rmse:4.82901	test-rmse:5.36519
# [185]	train-rmse:4.82389	test-rmse:5.36226
# [186]	train-rmse:4.82138	test-rmse:5.361
# [187]	train-rmse:4.81906	test-rmse:5.35887
# [188]	train-rmse:4.81668	test-rmse:5.35686
# [189]	train-rmse:4.81301	test-rmse:5.35556
# [190]	train-rmse:4.81192	test-rmse:5.35457
# [191]	train-rmse:4.8076	test-rmse:5.35318
# [192]	train-rmse:4.8048	test-rmse:5.35135
# [193]	train-rmse:4.80283	test-rmse:5.34997
# [194]	train-rmse:4.8016	test-rmse:5.34816
# [195]	train-rmse:4.80002	test-rmse:5.34552
# [196]	train-rmse:4.79839	test-rmse:5.34236
# [197]	train-rmse:4.79539	test-rmse:5.34109
# [198]	train-rmse:4.79031	test-rmse:5.34017
# [199]	train-rmse:4.78822	test-rmse:5.33894
# [200]	train-rmse:4.78618	test-rmse:5.33567
# [201]	train-rmse:4.78065	test-rmse:5.32852
# [202]	train-rmse:4.77436	test-rmse:5.32425
# [203]	train-rmse:4.7699	test-rmse:5.32276
# [204]	train-rmse:4.76675	test-rmse:5.32151
# [205]	train-rmse:4.76483	test-rmse:5.32047
# [206]	train-rmse:4.76318	test-rmse:5.32
# [207]	train-rmse:4.76024	test-rmse:5.31652
# [208]	train-rmse:4.75671	test-rmse:5.3152
# [209]	train-rmse:4.75389	test-rmse:5.31128
# [210]	train-rmse:4.7521	test-rmse:5.31031
# [211]	train-rmse:4.74599	test-rmse:5.30869
# [212]	train-rmse:4.74315	test-rmse:5.30621
# [213]	train-rmse:4.73943	test-rmse:5.30527
# [214]	train-rmse:4.73693	test-rmse:5.30413
# [215]	train-rmse:4.73552	test-rmse:5.3031
# [216]	train-rmse:4.72897	test-rmse:5.30179
# [217]	train-rmse:4.72405	test-rmse:5.30021
# [218]	train-rmse:4.71868	test-rmse:5.2952
# [219]	train-rmse:4.71391	test-rmse:5.29283
# [220]	train-rmse:4.71034	test-rmse:5.29147
# [221]	train-rmse:4.70847	test-rmse:5.28975
# [222]	train-rmse:4.7046	test-rmse:5.28927
# [223]	train-rmse:4.70095	test-rmse:5.28688
# [224]	train-rmse:4.69863	test-rmse:5.28545
# [225]	train-rmse:4.69759	test-rmse:5.28438
# [226]	train-rmse:4.69305	test-rmse:5.28271
# [227]	train-rmse:4.68831	test-rmse:5.2807
# [228]	train-rmse:4.68311	test-rmse:5.27845
# [229]	train-rmse:4.68043	test-rmse:5.27772
# [230]	train-rmse:4.678	test-rmse:5.27711
# [231]	train-rmse:4.67614	test-rmse:5.27594
# [232]	train-rmse:4.67202	test-rmse:5.27281
# [233]	train-rmse:4.66766	test-rmse:5.27085
# [234]	train-rmse:4.66566	test-rmse:5.27024
# [235]	train-rmse:4.6626	test-rmse:5.26948
# [236]	train-rmse:4.65939	test-rmse:5.26866
# [237]	train-rmse:4.65767	test-rmse:5.26771
# [238]	train-rmse:4.65338	test-rmse:5.26491
# [239]	train-rmse:4.65169	test-rmse:5.26405
# [240]	train-rmse:4.64787	test-rmse:5.26
# [241]	train-rmse:4.64403	test-rmse:5.25858
# [242]	train-rmse:4.64254	test-rmse:5.25668
# [243]	train-rmse:4.63928	test-rmse:5.25489
# [244]	train-rmse:4.63779	test-rmse:5.25406
# [245]	train-rmse:4.63509	test-rmse:5.25315
# [246]	train-rmse:4.6336	test-rmse:5.25183
# [247]	train-rmse:4.63047	test-rmse:5.25004
# [248]	train-rmse:4.62822	test-rmse:5.24944
# [249]	train-rmse:4.62651	test-rmse:5.24871
# [250]	train-rmse:4.62477	test-rmse:5.24763
# [251]	train-rmse:4.62025	test-rmse:5.24575
# [252]	train-rmse:4.61886	test-rmse:5.24479
# [253]	train-rmse:4.61644	test-rmse:5.24381
# [254]	train-rmse:4.61483	test-rmse:5.24305
# [255]	train-rmse:4.61312	test-rmse:5.24125
# [256]	train-rmse:4.61061	test-rmse:5.2398
# [257]	train-rmse:4.60944	test-rmse:5.23903
# [258]	train-rmse:4.60885	test-rmse:5.23863
# [259]	train-rmse:4.60766	test-rmse:5.23828
# [260]	train-rmse:4.60478	test-rmse:5.23349
# [261]	train-rmse:4.60416	test-rmse:5.23316
# [262]	train-rmse:4.6024	test-rmse:5.23199
# [263]	train-rmse:4.59821	test-rmse:5.23051
# [264]	train-rmse:4.59666	test-rmse:5.22905
# [265]	train-rmse:4.59115	test-rmse:5.22825
# [266]	train-rmse:4.58832	test-rmse:5.22611
# [267]	train-rmse:4.58724	test-rmse:5.22493
# [268]	train-rmse:4.5856	test-rmse:5.22352
# [269]	train-rmse:4.58424	test-rmse:5.22242
# [270]	train-rmse:4.58303	test-rmse:5.22236
# [271]	train-rmse:4.58035	test-rmse:5.22107
# [272]	train-rmse:4.57844	test-rmse:5.22057
# [273]	train-rmse:4.57716	test-rmse:5.21867
# [274]	train-rmse:4.5762	test-rmse:5.21874
# [275]	train-rmse:4.57355	test-rmse:5.21633
# [276]	train-rmse:4.57096	test-rmse:5.21597
# [277]	train-rmse:4.5693	test-rmse:5.21572
# [278]	train-rmse:4.56657	test-rmse:5.21436
# [279]	train-rmse:4.56549	test-rmse:5.21275
# [280]	train-rmse:4.56284	test-rmse:5.21063
# [281]	train-rmse:4.56089	test-rmse:5.21006
# [282]	train-rmse:4.55837	test-rmse:5.20882
# [283]	train-rmse:4.55756	test-rmse:5.20844
# [284]	train-rmse:4.55717	test-rmse:5.2083
# [285]	train-rmse:4.55413	test-rmse:5.20782
# [286]	train-rmse:4.55278	test-rmse:5.20663
# [287]	train-rmse:4.55112	test-rmse:5.20606
# [288]	train-rmse:4.54844	test-rmse:5.20524
# [289]	train-rmse:4.54749	test-rmse:5.20451
# [290]	train-rmse:4.54586	test-rmse:5.20377
# [291]	train-rmse:4.5452	test-rmse:5.203
# [292]	train-rmse:4.54259	test-rmse:5.20171
# [293]	train-rmse:4.54015	test-rmse:5.20125
# [294]	train-rmse:4.53906	test-rmse:5.20043
# [295]	train-rmse:4.53615	test-rmse:5.19916
# [296]	train-rmse:4.53548	test-rmse:5.1987
# [297]	train-rmse:4.53432	test-rmse:5.19827
# [298]	train-rmse:4.53224	test-rmse:5.19772
# [299]	train-rmse:4.53175	test-rmse:5.19737
# [300]	train-rmse:4.52893	test-rmse:5.19591
# [301]	train-rmse:4.52651	test-rmse:5.19552
# [302]	train-rmse:4.52401	test-rmse:5.195
# [303]	train-rmse:4.52335	test-rmse:5.1947
# [304]	train-rmse:4.52086	test-rmse:5.1949
# [305]	train-rmse:4.51982	test-rmse:5.19321
# [306]	train-rmse:4.51837	test-rmse:5.19213
# [307]	train-rmse:4.51602	test-rmse:5.19138
# [308]	train-rmse:4.51405	test-rmse:5.19011
# [309]	train-rmse:4.51293	test-rmse:5.18913
# [310]	train-rmse:4.51081	test-rmse:5.18762
# [311]	train-rmse:4.50904	test-rmse:5.18719
# [312]	train-rmse:4.50752	test-rmse:5.18622
# [313]	train-rmse:4.50643	test-rmse:5.18562
# [314]	train-rmse:4.50445	test-rmse:5.18522
# [315]	train-rmse:4.5036	test-rmse:5.18466
# [316]	train-rmse:4.50156	test-rmse:5.18247
# [317]	train-rmse:4.49938	test-rmse:5.18092
# [318]	train-rmse:4.4965	test-rmse:5.18054
# [319]	train-rmse:4.49481	test-rmse:5.17846
# [320]	train-rmse:4.49408	test-rmse:5.17778
# [321]	train-rmse:4.49267	test-rmse:5.17614
# [322]	train-rmse:4.4897	test-rmse:5.17596
# [323]	train-rmse:4.48831	test-rmse:5.17563
# [324]	train-rmse:4.48566	test-rmse:5.17506
# [325]	train-rmse:4.4847	test-rmse:5.17451
# [326]	train-rmse:4.48294	test-rmse:5.1717
# [327]	train-rmse:4.48184	test-rmse:5.17114
# [328]	train-rmse:4.47932	test-rmse:5.17005
# [329]	train-rmse:4.47777	test-rmse:5.16924
# [330]	train-rmse:4.47392	test-rmse:5.16812
# [331]	train-rmse:4.47175	test-rmse:5.16708
# [332]	train-rmse:4.47087	test-rmse:5.16646
# [333]	train-rmse:4.46925	test-rmse:5.16592
# [334]	train-rmse:4.46556	test-rmse:5.16419
# [335]	train-rmse:4.46393	test-rmse:5.16361
# [336]	train-rmse:4.46231	test-rmse:5.16194
# [337]	train-rmse:4.46167	test-rmse:5.16142
# [338]	train-rmse:4.45982	test-rmse:5.15894
# [339]	train-rmse:4.45885	test-rmse:5.15813
# [340]	train-rmse:4.45647	test-rmse:5.15716
# [341]	train-rmse:4.45203	test-rmse:5.15499
# [342]	train-rmse:4.4506	test-rmse:5.15387
# [343]	train-rmse:4.4479	test-rmse:5.15067
# [344]	train-rmse:4.44619	test-rmse:5.14988
# [345]	train-rmse:4.44549	test-rmse:5.149
# [346]	train-rmse:4.44395	test-rmse:5.14844
# [347]	train-rmse:4.44257	test-rmse:5.14715
# [348]	train-rmse:4.44204	test-rmse:5.14667
# [349]	train-rmse:4.43998	test-rmse:5.1443
# [350]	train-rmse:4.43674	test-rmse:5.1404
# [351]	train-rmse:4.43596	test-rmse:5.14037
# [352]	train-rmse:4.43295	test-rmse:5.1387
# [353]	train-rmse:4.43173	test-rmse:5.13739
# [354]	train-rmse:4.42775	test-rmse:5.13386
# [355]	train-rmse:4.42545	test-rmse:5.13292
# [356]	train-rmse:4.42072	test-rmse:5.13258
# [357]	train-rmse:4.41975	test-rmse:5.13218
# [358]	train-rmse:4.41909	test-rmse:5.13185
# [359]	train-rmse:4.41824	test-rmse:5.13149
# [360]	train-rmse:4.41773	test-rmse:5.13108
# [361]	train-rmse:4.4168	test-rmse:5.13028
# [362]	train-rmse:4.41576	test-rmse:5.12941
# [363]	train-rmse:4.41314	test-rmse:5.1289
# [364]	train-rmse:4.41089	test-rmse:5.12654
# [365]	train-rmse:4.40963	test-rmse:5.12581
# [366]	train-rmse:4.40899	test-rmse:5.12509
# [367]	train-rmse:4.40755	test-rmse:5.12464
# [368]	train-rmse:4.40657	test-rmse:5.12353
# [369]	train-rmse:4.40572	test-rmse:5.12343
# [370]	train-rmse:4.40529	test-rmse:5.12315
# [371]	train-rmse:4.40483	test-rmse:5.12286
# [372]	train-rmse:4.40381	test-rmse:5.12259
# [373]	train-rmse:4.40268	test-rmse:5.12175
# [374]	train-rmse:4.40037	test-rmse:5.12141
# [375]	train-rmse:4.39983	test-rmse:5.12082
# [376]	train-rmse:4.39696	test-rmse:5.12117
# [377]	train-rmse:4.39499	test-rmse:5.12017
# [378]	train-rmse:4.39304	test-rmse:5.11666
# [379]	train-rmse:4.3914	test-rmse:5.11563
# [380]	train-rmse:4.38798	test-rmse:5.11485
# [381]	train-rmse:4.38569	test-rmse:5.11441
# [382]	train-rmse:4.38227	test-rmse:5.11341
# [383]	train-rmse:4.38085	test-rmse:5.11158
# [384]	train-rmse:4.38018	test-rmse:5.11115
# [385]	train-rmse:4.37911	test-rmse:5.11054
# [386]	train-rmse:4.37732	test-rmse:5.11027
# [387]	train-rmse:4.37677	test-rmse:5.10997
# [388]	train-rmse:4.37445	test-rmse:5.10928
# [389]	train-rmse:4.37336	test-rmse:5.10864
# [390]	train-rmse:4.373	test-rmse:5.10849
# [391]	train-rmse:4.37028	test-rmse:5.10814
# [392]	train-rmse:4.3693	test-rmse:5.10861
# [393]	train-rmse:4.36883	test-rmse:5.10832
# [394]	train-rmse:4.36824	test-rmse:5.10765
# [395]	train-rmse:4.3658	test-rmse:5.10679
# [396]	train-rmse:4.36436	test-rmse:5.10739
# [397]	train-rmse:4.36376	test-rmse:5.10712
# [398]	train-rmse:4.36338	test-rmse:5.10687
# [399]	train-rmse:4.36066	test-rmse:5.1061
# [400]	train-rmse:4.35844	test-rmse:5.10531
# [401]	train-rmse:4.35622	test-rmse:5.10505
# [402]	train-rmse:4.35525	test-rmse:5.10401
# [403]	train-rmse:4.35427	test-rmse:5.10386
# [404]	train-rmse:4.35316	test-rmse:5.10259
# [405]	train-rmse:4.35103	test-rmse:5.1019
# [406]	train-rmse:4.34961	test-rmse:5.10084
# [407]	train-rmse:4.34769	test-rmse:5.10137
# [408]	train-rmse:4.34619	test-rmse:5.10105
# [409]	train-rmse:4.34498	test-rmse:5.10049
# [410]	train-rmse:4.34225	test-rmse:5.09952
# [411]	train-rmse:4.34128	test-rmse:5.09935
# [412]	train-rmse:4.33931	test-rmse:5.09828
# [413]	train-rmse:4.33861	test-rmse:5.09753
# [414]	train-rmse:4.33593	test-rmse:5.0968
# [415]	train-rmse:4.33504	test-rmse:5.09604
# [416]	train-rmse:4.33373	test-rmse:5.09579
# [417]	train-rmse:4.33187	test-rmse:5.09357
# [418]	train-rmse:4.33077	test-rmse:5.09277
# [419]	train-rmse:4.33003	test-rmse:5.09277
# [420]	train-rmse:4.32859	test-rmse:5.09245
# [421]	train-rmse:4.32601	test-rmse:5.09238
# [422]	train-rmse:4.32527	test-rmse:5.09209
# [423]	train-rmse:4.32427	test-rmse:5.09177
# [424]	train-rmse:4.32369	test-rmse:5.09148
# [425]	train-rmse:4.3212	test-rmse:5.0909
# [426]	train-rmse:4.31822	test-rmse:5.08942
# [427]	train-rmse:4.31717	test-rmse:5.08861
# [428]	train-rmse:4.31601	test-rmse:5.08746
# [429]	train-rmse:4.31544	test-rmse:5.08717
# [430]	train-rmse:4.31453	test-rmse:5.08675
# [431]	train-rmse:4.31165	test-rmse:5.08643
# [432]	train-rmse:4.31097	test-rmse:5.08605
# [433]	train-rmse:4.30851	test-rmse:5.08534
# [434]	train-rmse:4.30726	test-rmse:5.08478
# [435]	train-rmse:4.30526	test-rmse:5.08401
# [436]	train-rmse:4.30242	test-rmse:5.08195
# [437]	train-rmse:4.30101	test-rmse:5.08158
# [438]	train-rmse:4.30023	test-rmse:5.0814
# [439]	train-rmse:4.29799	test-rmse:5.07995
# [440]	train-rmse:4.29699	test-rmse:5.07904
# [441]	train-rmse:4.29647	test-rmse:5.07886
# [442]	train-rmse:4.29577	test-rmse:5.07862
# [443]	train-rmse:4.29468	test-rmse:5.078
# [444]	train-rmse:4.29146	test-rmse:5.07731
# [445]	train-rmse:4.2901	test-rmse:5.07635
# [446]	train-rmse:4.28966	test-rmse:5.07626
# [447]	train-rmse:4.28883	test-rmse:5.07591
# [448]	train-rmse:4.28802	test-rmse:5.07579
# [449]	train-rmse:4.28744	test-rmse:5.07535
# [450]	train-rmse:4.28678	test-rmse:5.07486
# [451]	train-rmse:4.28499	test-rmse:5.07434
# [452]	train-rmse:4.28393	test-rmse:5.07357
# [453]	train-rmse:4.28335	test-rmse:5.0731
# [454]	train-rmse:4.28194	test-rmse:5.07266
# [455]	train-rmse:4.28155	test-rmse:5.07243
# [456]	train-rmse:4.28092	test-rmse:5.0722
# [457]	train-rmse:4.27954	test-rmse:5.07199
# [458]	train-rmse:4.27797	test-rmse:5.07109
# [459]	train-rmse:4.27667	test-rmse:5.07216
# [460]	train-rmse:4.27455	test-rmse:5.06992
# [461]	train-rmse:4.2701	test-rmse:5.07058
# [462]	train-rmse:4.26946	test-rmse:5.07004
# [463]	train-rmse:4.26797	test-rmse:5.07007
# [464]	train-rmse:4.2671	test-rmse:5.07093
# [465]	train-rmse:4.26536	test-rmse:5.06764
# [466]	train-rmse:4.26465	test-rmse:5.06715
# [467]	train-rmse:4.26375	test-rmse:5.06621
# [468]	train-rmse:4.26107	test-rmse:5.0657
# [469]	train-rmse:4.25962	test-rmse:5.06522
# [470]	train-rmse:4.25907	test-rmse:5.06463
# [471]	train-rmse:4.2584	test-rmse:5.06429
# [472]	train-rmse:4.25567	test-rmse:5.0638
# [473]	train-rmse:4.25472	test-rmse:5.06307
# [474]	train-rmse:4.25427	test-rmse:5.06286
# [475]	train-rmse:4.25189	test-rmse:5.06045
# [476]	train-rmse:4.25057	test-rmse:5.06101
# [477]	train-rmse:4.24932	test-rmse:5.06067
# [478]	train-rmse:4.24682	test-rmse:5.05865
# [479]	train-rmse:4.24563	test-rmse:5.05857
# [480]	train-rmse:4.24516	test-rmse:5.05841
# [481]	train-rmse:4.24471	test-rmse:5.0581
# [482]	train-rmse:4.24294	test-rmse:5.05632
# [483]	train-rmse:4.2425	test-rmse:5.05632
# [484]	train-rmse:4.24113	test-rmse:5.05633
# [485]	train-rmse:4.23999	test-rmse:5.05604
# [486]	train-rmse:4.23932	test-rmse:5.05536
# [487]	train-rmse:4.23703	test-rmse:5.05348
# [488]	train-rmse:4.23564	test-rmse:5.05358
# [489]	train-rmse:4.23374	test-rmse:5.05271
# [490]	train-rmse:4.23281	test-rmse:5.05222
# [491]	train-rmse:4.23132	test-rmse:5.05
# [492]	train-rmse:4.23093	test-rmse:5.04972
# [493]	train-rmse:4.22775	test-rmse:5.0488
# [494]	train-rmse:4.22735	test-rmse:5.04843
# [495]	train-rmse:4.22662	test-rmse:5.04835
# [496]	train-rmse:4.2252	test-rmse:5.0473
# [497]	train-rmse:4.22344	test-rmse:5.04507
# [498]	train-rmse:4.2229	test-rmse:5.04462
# [499]	train-rmse:4.22226	test-rmse:5.04436
# [500]	train-rmse:4.2217	test-rmse:5.0441
# [501]	train-rmse:4.22128	test-rmse:5.04384
# [502]	train-rmse:4.22033	test-rmse:5.04366
# [503]	train-rmse:4.21924	test-rmse:5.04315
# [504]	train-rmse:4.21687	test-rmse:5.04297
# [505]	train-rmse:4.21446	test-rmse:5.04274
# [506]	train-rmse:4.21338	test-rmse:5.04235
# [507]	train-rmse:4.21299	test-rmse:5.04217
# [508]	train-rmse:4.21171	test-rmse:5.04174
# [509]	train-rmse:4.20983	test-rmse:5.04107
# [510]	train-rmse:4.20785	test-rmse:5.04059
# [511]	train-rmse:4.20671	test-rmse:5.04035
# [512]	train-rmse:4.20597	test-rmse:5.04053
# [513]	train-rmse:4.20415	test-rmse:5.03859
# [514]	train-rmse:4.2036	test-rmse:5.0383
# [515]	train-rmse:4.20311	test-rmse:5.03811
# [516]	train-rmse:4.20103	test-rmse:5.03578
# [517]	train-rmse:4.1991	test-rmse:5.03403
# [518]	train-rmse:4.19765	test-rmse:5.03391
# [519]	train-rmse:4.19479	test-rmse:5.03297
# [520]	train-rmse:4.19442	test-rmse:5.03275
# [521]	train-rmse:4.19369	test-rmse:5.03171
# [522]	train-rmse:4.19322	test-rmse:5.03156
# [523]	train-rmse:4.1926	test-rmse:5.03137
# [524]	train-rmse:4.19231	test-rmse:5.03112
# [525]	train-rmse:4.19197	test-rmse:5.03095
# [526]	train-rmse:4.19109	test-rmse:5.03079
# [527]	train-rmse:4.18977	test-rmse:5.03026
# [528]	train-rmse:4.18939	test-rmse:5.03008
# [529]	train-rmse:4.1882	test-rmse:5.02982
# [530]	train-rmse:4.18703	test-rmse:5.02904
# [531]	train-rmse:4.1865	test-rmse:5.02872
# [532]	train-rmse:4.18587	test-rmse:5.02819
# [533]	train-rmse:4.18496	test-rmse:5.0278
# [534]	train-rmse:4.18433	test-rmse:5.02725
# [535]	train-rmse:4.18371	test-rmse:5.02653
# [536]	train-rmse:4.18269	test-rmse:5.02625
# [537]	train-rmse:4.18201	test-rmse:5.02572
# [538]	train-rmse:4.17999	test-rmse:5.02417
# [539]	train-rmse:4.17967	test-rmse:5.024
# [540]	train-rmse:4.17899	test-rmse:5.02418
# [541]	train-rmse:4.17762	test-rmse:5.02419
# [542]	train-rmse:4.17693	test-rmse:5.02423
# [543]	train-rmse:4.17637	test-rmse:5.02395
# [544]	train-rmse:4.17616	test-rmse:5.02379
# [545]	train-rmse:4.1756	test-rmse:5.02267
# [546]	train-rmse:4.17427	test-rmse:5.02219
# [547]	train-rmse:4.17245	test-rmse:5.02083
# [548]	train-rmse:4.17158	test-rmse:5.02064
# [549]	train-rmse:4.17091	test-rmse:5.02019
# [550]	train-rmse:4.17025	test-rmse:5.01958
# [551]	train-rmse:4.16914	test-rmse:5.01902
# [552]	train-rmse:4.16869	test-rmse:5.0189
# [553]	train-rmse:4.16771	test-rmse:5.01878
# [554]	train-rmse:4.167	test-rmse:5.01837
# [555]	train-rmse:4.16613	test-rmse:5.01482
# [556]	train-rmse:4.16517	test-rmse:5.01459
# [557]	train-rmse:4.16353	test-rmse:5.01434
# [558]	train-rmse:4.16314	test-rmse:5.01411
# [559]	train-rmse:4.16255	test-rmse:5.01371
# [560]	train-rmse:4.16092	test-rmse:5.01128
# [561]	train-rmse:4.16024	test-rmse:5.01123
# [562]	train-rmse:4.15939	test-rmse:5.01098
# [563]	train-rmse:4.15905	test-rmse:5.01074
# [564]	train-rmse:4.15853	test-rmse:5.01099
# [565]	train-rmse:4.15802	test-rmse:5.01069
# [566]	train-rmse:4.15684	test-rmse:5.00988
# [567]	train-rmse:4.15659	test-rmse:5.00975
# [568]	train-rmse:4.15579	test-rmse:5.00929
# [569]	train-rmse:4.15314	test-rmse:5.00893
# [570]	train-rmse:4.15215	test-rmse:5.009
# [571]	train-rmse:4.15168	test-rmse:5.00876
# [572]	train-rmse:4.15097	test-rmse:5.00824
# [573]	train-rmse:4.15031	test-rmse:5.008
# [574]	train-rmse:4.14998	test-rmse:5.00785
# [575]	train-rmse:4.14898	test-rmse:5.00721
# [576]	train-rmse:4.14621	test-rmse:5.00625
# [577]	train-rmse:4.14518	test-rmse:5.0052
# [578]	train-rmse:4.14445	test-rmse:5.0046
# [579]	train-rmse:4.14382	test-rmse:5.00386
# [580]	train-rmse:4.14151	test-rmse:5.00254
# [581]	train-rmse:4.14049	test-rmse:5.00178
# [582]	train-rmse:4.14001	test-rmse:5.00165
# [583]	train-rmse:4.13892	test-rmse:5.00096
# [584]	train-rmse:4.1369	test-rmse:5.00027
# [585]	train-rmse:4.13467	test-rmse:5.00011
# [586]	train-rmse:4.13408	test-rmse:4.99961
# [587]	train-rmse:4.13288	test-rmse:4.99902
# [588]	train-rmse:4.13213	test-rmse:4.99787
# [589]	train-rmse:4.13007	test-rmse:4.99677
# [590]	train-rmse:4.12882	test-rmse:4.9959
# [591]	train-rmse:4.12837	test-rmse:4.99569
# [592]	train-rmse:4.12798	test-rmse:4.99554
# [593]	train-rmse:4.12731	test-rmse:4.99523
# [594]	train-rmse:4.12604	test-rmse:4.99497
# [595]	train-rmse:4.12551	test-rmse:4.99457
# [596]	train-rmse:4.12475	test-rmse:4.99403
# [597]	train-rmse:4.12425	test-rmse:4.9936
# [598]	train-rmse:4.12362	test-rmse:4.9931
# [599]	train-rmse:4.12316	test-rmse:4.99291
# [600]	train-rmse:4.12208	test-rmse:4.99143
# [601]	train-rmse:4.12183	test-rmse:4.99129
# [602]	train-rmse:4.12102	test-rmse:4.99121
# [603]	train-rmse:4.11989	test-rmse:4.99067
# [604]	train-rmse:4.11814	test-rmse:4.98994
# [605]	train-rmse:4.11737	test-rmse:4.98979
# [606]	train-rmse:4.11531	test-rmse:4.9888
# [607]	train-rmse:4.11432	test-rmse:4.98855
# [608]	train-rmse:4.11402	test-rmse:4.98833
# [609]	train-rmse:4.11343	test-rmse:4.98791
# [610]	train-rmse:4.11296	test-rmse:4.98771
# [611]	train-rmse:4.11271	test-rmse:4.98757
# [612]	train-rmse:4.1112	test-rmse:4.98676
# [613]	train-rmse:4.11086	test-rmse:4.9866
# [614]	train-rmse:4.11047	test-rmse:4.98637
# [615]	train-rmse:4.11013	test-rmse:4.98593
# [616]	train-rmse:4.10979	test-rmse:4.98569
# [617]	train-rmse:4.10902	test-rmse:4.98525
# [618]	train-rmse:4.10873	test-rmse:4.98505
# [619]	train-rmse:4.10779	test-rmse:4.9843
# [620]	train-rmse:4.10699	test-rmse:4.9842
# [621]	train-rmse:4.10531	test-rmse:4.98377
# [622]	train-rmse:4.10368	test-rmse:4.98297
# [623]	train-rmse:4.10255	test-rmse:4.98246
# [624]	train-rmse:4.10188	test-rmse:4.98066
# [625]	train-rmse:4.10126	test-rmse:4.98056
# [626]	train-rmse:4.10071	test-rmse:4.98018
# [627]	train-rmse:4.09866	test-rmse:4.97937
# [628]	train-rmse:4.09724	test-rmse:4.97564
# [629]	train-rmse:4.09572	test-rmse:4.97521
# [630]	train-rmse:4.09487	test-rmse:4.97457
# [631]	train-rmse:4.09365	test-rmse:4.97383
# [632]	train-rmse:4.09265	test-rmse:4.97382
# [633]	train-rmse:4.09112	test-rmse:4.97306
# [634]	train-rmse:4.09019	test-rmse:4.97277
# [635]	train-rmse:4.08729	test-rmse:4.96986
# [636]	train-rmse:4.08674	test-rmse:4.96969
# [637]	train-rmse:4.08555	test-rmse:4.96867
# [638]	train-rmse:4.08466	test-rmse:4.96723
# [639]	train-rmse:4.08376	test-rmse:4.967
# [640]	train-rmse:4.0828	test-rmse:4.96676
# [641]	train-rmse:4.08134	test-rmse:4.96663
# [642]	train-rmse:4.08059	test-rmse:4.96599
# [643]	train-rmse:4.07841	test-rmse:4.96559
# [644]	train-rmse:4.07666	test-rmse:4.96547
# [645]	train-rmse:4.0763	test-rmse:4.96521
# [646]	train-rmse:4.07538	test-rmse:4.96496
# [647]	train-rmse:4.07478	test-rmse:4.96478
# [648]	train-rmse:4.07297	test-rmse:4.96443
# [649]	train-rmse:4.07068	test-rmse:4.96415
# [650]	train-rmse:4.06991	test-rmse:4.96373
# [651]	train-rmse:4.06733	test-rmse:4.96085
# [652]	train-rmse:4.06477	test-rmse:4.95978
# [653]	train-rmse:4.06318	test-rmse:4.9581
# [654]	train-rmse:4.06293	test-rmse:4.95797
# [655]	train-rmse:4.06234	test-rmse:4.95779
# [656]	train-rmse:4.06157	test-rmse:4.95735
# [657]	train-rmse:4.05888	test-rmse:4.95652
# [658]	train-rmse:4.05675	test-rmse:4.95715
# [659]	train-rmse:4.05556	test-rmse:4.95635
# [660]	train-rmse:4.05505	test-rmse:4.95614
# [661]	train-rmse:4.05481	test-rmse:4.95582
# [662]	train-rmse:4.05273	test-rmse:4.95556
# [663]	train-rmse:4.05232	test-rmse:4.95518
# [664]	train-rmse:4.05113	test-rmse:4.95467
# [665]	train-rmse:4.05069	test-rmse:4.95425
# [666]	train-rmse:4.04999	test-rmse:4.95386
# [667]	train-rmse:4.0493	test-rmse:4.95339
# [668]	train-rmse:4.04851	test-rmse:4.95331
# [669]	train-rmse:4.04766	test-rmse:4.95309
# [670]	train-rmse:4.0474	test-rmse:4.95292
# [671]	train-rmse:4.04673	test-rmse:4.95249
# [672]	train-rmse:4.04636	test-rmse:4.95234
# [673]	train-rmse:4.04589	test-rmse:4.95201
# [674]	train-rmse:4.04563	test-rmse:4.95188
# [675]	train-rmse:4.0443	test-rmse:4.95082
# [676]	train-rmse:4.04403	test-rmse:4.95071
# [677]	train-rmse:4.04254	test-rmse:4.95053
# [678]	train-rmse:4.04227	test-rmse:4.95039
# [679]	train-rmse:4.04097	test-rmse:4.94933
# [680]	train-rmse:4.04061	test-rmse:4.94936
# [681]	train-rmse:4.03823	test-rmse:4.94957
# [682]	train-rmse:4.03553	test-rmse:4.94838
# [683]	train-rmse:4.03534	test-rmse:4.94835
# [684]	train-rmse:4.03514	test-rmse:4.94823
# [685]	train-rmse:4.03294	test-rmse:4.94698
# [686]	train-rmse:4.0309	test-rmse:4.94604
# [687]	train-rmse:4.03008	test-rmse:4.94506
# [688]	train-rmse:4.02904	test-rmse:4.94295
# [689]	train-rmse:4.02882	test-rmse:4.94284
# [690]	train-rmse:4.02696	test-rmse:4.9426
# [691]	train-rmse:4.02622	test-rmse:4.94223
# [692]	train-rmse:4.02366	test-rmse:4.94132
# [693]	train-rmse:4.02328	test-rmse:4.9412
# [694]	train-rmse:4.02229	test-rmse:4.93918
# [695]	train-rmse:4.02157	test-rmse:4.93875
# [696]	train-rmse:4.02096	test-rmse:4.93858
# [697]	train-rmse:4.02067	test-rmse:4.93845
# [698]	train-rmse:4.01954	test-rmse:4.93775
# [699]	train-rmse:4.01735	test-rmse:4.93379
# [700]	train-rmse:4.01704	test-rmse:4.93362
# [701]	train-rmse:4.01666	test-rmse:4.93333
# [702]	train-rmse:4.01626	test-rmse:4.93309
# [703]	train-rmse:4.01574	test-rmse:4.93287
# [704]	train-rmse:4.01423	test-rmse:4.93327
# [705]	train-rmse:4.01336	test-rmse:4.93264
# [706]	train-rmse:4.01284	test-rmse:4.93239
# [707]	train-rmse:4.01231	test-rmse:4.93229
# [708]	train-rmse:4.0108	test-rmse:4.93087
# [709]	train-rmse:4.01045	test-rmse:4.9306
# [710]	train-rmse:4.00916	test-rmse:4.93048
# [711]	train-rmse:4.00896	test-rmse:4.93034
# [712]	train-rmse:4.00821	test-rmse:4.93014
# [713]	train-rmse:4.00713	test-rmse:4.9299
# [714]	train-rmse:4.00571	test-rmse:4.93119
# [715]	train-rmse:4.00406	test-rmse:4.92981
# [716]	train-rmse:4.00198	test-rmse:4.93117
# [717]	train-rmse:4.00167	test-rmse:4.93092
# [718]	train-rmse:4.00129	test-rmse:4.93068
# [719]	train-rmse:4.00103	test-rmse:4.93058
# [720]	train-rmse:3.99964	test-rmse:4.92946
# [721]	train-rmse:3.99927	test-rmse:4.92921
# [722]	train-rmse:3.99841	test-rmse:4.92827
# [723]	train-rmse:3.99735	test-rmse:4.92775
# [724]	train-rmse:3.99617	test-rmse:4.92732
# [725]	train-rmse:3.99566	test-rmse:4.92675
# [726]	train-rmse:3.99415	test-rmse:4.92653
# [727]	train-rmse:3.99169	test-rmse:4.92512
# [728]	train-rmse:3.99042	test-rmse:4.92322
# [729]	train-rmse:3.98995	test-rmse:4.92309
# [730]	train-rmse:3.98919	test-rmse:4.92264
# [731]	train-rmse:3.98827	test-rmse:4.92203
# [732]	train-rmse:3.98772	test-rmse:4.92171
# [733]	train-rmse:3.98733	test-rmse:4.92118
# [734]	train-rmse:3.98649	test-rmse:4.92076
# [735]	train-rmse:3.98587	test-rmse:4.92044
# [736]	train-rmse:3.98565	test-rmse:4.92035
# [737]	train-rmse:3.98502	test-rmse:4.91982
# [738]	train-rmse:3.98312	test-rmse:4.91896
# [739]	train-rmse:3.98263	test-rmse:4.91868
# [740]	train-rmse:3.9821	test-rmse:4.91831
# [741]	train-rmse:3.98172	test-rmse:4.91801
# [742]	train-rmse:3.98004	test-rmse:4.91757
# [743]	train-rmse:3.97851	test-rmse:4.91721
# [744]	train-rmse:3.97757	test-rmse:4.917
# [745]	train-rmse:3.97729	test-rmse:4.91684
# [746]	train-rmse:3.97602	test-rmse:4.91623
# [747]	train-rmse:3.97557	test-rmse:4.91599
# [748]	train-rmse:3.97511	test-rmse:4.91572
# [749]	train-rmse:3.97424	test-rmse:4.91559
# [750]	train-rmse:3.9739	test-rmse:4.91551
# [751]	train-rmse:3.97308	test-rmse:4.91452
# [752]	train-rmse:3.9724	test-rmse:4.91426
# [753]	train-rmse:3.97206	test-rmse:4.91439
# [754]	train-rmse:3.97096	test-rmse:4.91424
# [755]	train-rmse:3.97006	test-rmse:4.91395
# [756]	train-rmse:3.96872	test-rmse:4.91349
# [757]	train-rmse:3.96835	test-rmse:4.91368
# [758]	train-rmse:3.96757	test-rmse:4.91355
# [759]	train-rmse:3.96659	test-rmse:4.91337
# [760]	train-rmse:3.9661	test-rmse:4.91282
# [761]	train-rmse:3.96513	test-rmse:4.91186
# [762]	train-rmse:3.96385	test-rmse:4.91126
# [763]	train-rmse:3.96357	test-rmse:4.91108
# [764]	train-rmse:3.96263	test-rmse:4.91092
# [765]	train-rmse:3.96224	test-rmse:4.91064
# [766]	train-rmse:3.9614	test-rmse:4.9112
# [767]	train-rmse:3.96062	test-rmse:4.91109
# [768]	train-rmse:3.95858	test-rmse:4.9109
# [769]	train-rmse:3.95778	test-rmse:4.91033
# [770]	train-rmse:3.95702	test-rmse:4.90916
# [771]	train-rmse:3.95602	test-rmse:4.90869
# [772]	train-rmse:3.95419	test-rmse:4.90762
# [773]	train-rmse:3.95362	test-rmse:4.90724
# [774]	train-rmse:3.95326	test-rmse:4.9069
# [775]	train-rmse:3.95247	test-rmse:4.90652
# [776]	train-rmse:3.95157	test-rmse:4.90621
# [777]	train-rmse:3.95034	test-rmse:4.90718
# [778]	train-rmse:3.94999	test-rmse:4.90699
# [779]	train-rmse:3.94922	test-rmse:4.9061
# [780]	train-rmse:3.94765	test-rmse:4.90608
# [781]	train-rmse:3.94702	test-rmse:4.90589
# [782]	train-rmse:3.94676	test-rmse:4.90574
# [783]	train-rmse:3.94611	test-rmse:4.90568
# [784]	train-rmse:3.94504	test-rmse:4.90539
# [785]	train-rmse:3.94302	test-rmse:4.90474
# [786]	train-rmse:3.94236	test-rmse:4.90478
# [787]	train-rmse:3.94141	test-rmse:4.90413
# [788]	train-rmse:3.94046	test-rmse:4.90366
# [789]	train-rmse:3.9389	test-rmse:4.90278
# [790]	train-rmse:3.93841	test-rmse:4.9028
# [791]	train-rmse:3.93788	test-rmse:4.90267
# [792]	train-rmse:3.93681	test-rmse:4.90208
# [793]	train-rmse:3.93581	test-rmse:4.90113
# [794]	train-rmse:3.93457	test-rmse:4.90084
# [795]	train-rmse:3.93344	test-rmse:4.90081
# [796]	train-rmse:3.93274	test-rmse:4.90054
# [797]	train-rmse:3.93235	test-rmse:4.90027
# [798]	train-rmse:3.93199	test-rmse:4.90006
# [799]	train-rmse:3.93167	test-rmse:4.89986
# [800]	train-rmse:3.93148	test-rmse:4.8999
# [801]	train-rmse:3.93109	test-rmse:4.89971
# [802]	train-rmse:3.92996	test-rmse:4.8995
# [803]	train-rmse:3.92967	test-rmse:4.89937
# [804]	train-rmse:3.92928	test-rmse:4.89921
# [805]	train-rmse:3.92871	test-rmse:4.89863
# [806]	train-rmse:3.92784	test-rmse:4.89831
# [807]	train-rmse:3.92743	test-rmse:4.89808
# [808]	train-rmse:3.92658	test-rmse:4.89768
# [809]	train-rmse:3.92543	test-rmse:4.89756
# [810]	train-rmse:3.92512	test-rmse:4.89744
# [811]	train-rmse:3.92477	test-rmse:4.89737
# [812]	train-rmse:3.92443	test-rmse:4.89731
# [813]	train-rmse:3.92393	test-rmse:4.8969
# [814]	train-rmse:3.9233	test-rmse:4.8965
# [815]	train-rmse:3.92291	test-rmse:4.89626
# [816]	train-rmse:3.92163	test-rmse:4.89577
# [817]	train-rmse:3.92114	test-rmse:4.89512
# [818]	train-rmse:3.92004	test-rmse:4.89458
# [819]	train-rmse:3.91967	test-rmse:4.89427
# [820]	train-rmse:3.91928	test-rmse:4.89412
# [821]	train-rmse:3.91906	test-rmse:4.89396
# [822]	train-rmse:3.91781	test-rmse:4.89338
# [823]	train-rmse:3.91603	test-rmse:4.89169
# [824]	train-rmse:3.9153	test-rmse:4.8916
# [825]	train-rmse:3.91411	test-rmse:4.88887
# [826]	train-rmse:3.91298	test-rmse:4.88881
# [827]	train-rmse:3.91269	test-rmse:4.88871
# [828]	train-rmse:3.91174	test-rmse:4.88863
# [829]	train-rmse:3.91147	test-rmse:4.88841
# [830]	train-rmse:3.91088	test-rmse:4.88802
# [831]	train-rmse:3.91065	test-rmse:4.88789
# [832]	train-rmse:3.90984	test-rmse:4.88737
# [833]	train-rmse:3.90931	test-rmse:4.88713
# [834]	train-rmse:3.90905	test-rmse:4.88698
# [835]	train-rmse:3.90804	test-rmse:4.88662
# [836]	train-rmse:3.90774	test-rmse:4.8864
# [837]	train-rmse:3.90745	test-rmse:4.88625
# [838]	train-rmse:3.90711	test-rmse:4.88611
# [839]	train-rmse:3.90663	test-rmse:4.886
# [840]	train-rmse:3.90593	test-rmse:4.88541
# [841]	train-rmse:3.90531	test-rmse:4.88528
# [842]	train-rmse:3.9046	test-rmse:4.8849
# [843]	train-rmse:3.90416	test-rmse:4.88483
# [844]	train-rmse:3.90365	test-rmse:4.88465
# [845]	train-rmse:3.90308	test-rmse:4.88439
# [846]	train-rmse:3.9025	test-rmse:4.88401
# [847]	train-rmse:3.90126	test-rmse:4.88378
# [848]	train-rmse:3.90039	test-rmse:4.8835
# [849]	train-rmse:3.89972	test-rmse:4.88288
# [850]	train-rmse:3.89921	test-rmse:4.8827
# [851]	train-rmse:3.89868	test-rmse:4.8824
# [852]	train-rmse:3.89818	test-rmse:4.88231
# [853]	train-rmse:3.89665	test-rmse:4.88189
# [854]	train-rmse:3.8954	test-rmse:4.88079
# [855]	train-rmse:3.89468	test-rmse:4.87981
# [856]	train-rmse:3.89424	test-rmse:4.8797
# [857]	train-rmse:3.89356	test-rmse:4.8795
# [858]	train-rmse:3.8932	test-rmse:4.87934
# [859]	train-rmse:3.89218	test-rmse:4.87965
# [860]	train-rmse:3.89108	test-rmse:4.87955
# [861]	train-rmse:3.89013	test-rmse:4.87934
# [862]	train-rmse:3.88923	test-rmse:4.87634
# [863]	train-rmse:3.88815	test-rmse:4.87623
# [864]	train-rmse:3.88611	test-rmse:4.87605
# [865]	train-rmse:3.88531	test-rmse:4.87576
# [866]	train-rmse:3.88493	test-rmse:4.87532
# [867]	train-rmse:3.88417	test-rmse:4.87522
# [868]	train-rmse:3.88242	test-rmse:4.8755
# [869]	train-rmse:3.88184	test-rmse:4.87533
# [870]	train-rmse:3.88097	test-rmse:4.87553
# [871]	train-rmse:3.88053	test-rmse:4.87492
# [872]	train-rmse:3.87704	test-rmse:4.87426
# [873]	train-rmse:3.87611	test-rmse:4.87414
# [874]	train-rmse:3.87591	test-rmse:4.87404
# [875]	train-rmse:3.87564	test-rmse:4.87374
# [876]	train-rmse:3.8754	test-rmse:4.87368
# [877]	train-rmse:3.8743	test-rmse:4.87281
# [878]	train-rmse:3.8734	test-rmse:4.87159
# [879]	train-rmse:3.87263	test-rmse:4.87084
# [880]	train-rmse:3.87221	test-rmse:4.87049
# [881]	train-rmse:3.87174	test-rmse:4.87023
# [882]	train-rmse:3.87056	test-rmse:4.86979
# [883]	train-rmse:3.86966	test-rmse:4.86918
# [884]	train-rmse:3.86907	test-rmse:4.86864
# [885]	train-rmse:3.86815	test-rmse:4.86864
# [886]	train-rmse:3.86724	test-rmse:4.86701
# [887]	train-rmse:3.86702	test-rmse:4.86692
# [888]	train-rmse:3.86538	test-rmse:4.86738
# [889]	train-rmse:3.86488	test-rmse:4.86725
# [890]	train-rmse:3.86343	test-rmse:4.86623
# [891]	train-rmse:3.86035	test-rmse:4.86564
# [892]	train-rmse:3.8596	test-rmse:4.86534
# [893]	train-rmse:3.8594	test-rmse:4.86525
# [894]	train-rmse:3.85882	test-rmse:4.86459
# [895]	train-rmse:3.85841	test-rmse:4.86453
# [896]	train-rmse:3.85731	test-rmse:4.86426
# [897]	train-rmse:3.85688	test-rmse:4.86408
# [898]	train-rmse:3.85533	test-rmse:4.86383
# [899]	train-rmse:3.85493	test-rmse:4.8638
# [900]	train-rmse:3.85387	test-rmse:4.86374
# [901]	train-rmse:3.85293	test-rmse:4.86354
# [902]	train-rmse:3.85239	test-rmse:4.8631
# [903]	train-rmse:3.85138	test-rmse:4.86288
# [904]	train-rmse:3.84903	test-rmse:4.86295
# [905]	train-rmse:3.8487	test-rmse:4.8628
# [906]	train-rmse:3.84791	test-rmse:4.86273
# [907]	train-rmse:3.84757	test-rmse:4.86269
# [908]	train-rmse:3.84713	test-rmse:4.86255
# [909]	train-rmse:3.84622	test-rmse:4.8625
# [910]	train-rmse:3.84535	test-rmse:4.86177
# [911]	train-rmse:3.84439	test-rmse:4.86125
# [912]	train-rmse:3.84358	test-rmse:4.86068
# [913]	train-rmse:3.84309	test-rmse:4.86053
# [914]	train-rmse:3.84212	test-rmse:4.8602
# [915]	train-rmse:3.84168	test-rmse:4.86015
# [916]	train-rmse:3.84148	test-rmse:4.86013
# [917]	train-rmse:3.83959	test-rmse:4.85926
# [918]	train-rmse:3.83881	test-rmse:4.85898
# [919]	train-rmse:3.83769	test-rmse:4.85871
# [920]	train-rmse:3.8374	test-rmse:4.8586
# [921]	train-rmse:3.83708	test-rmse:4.85809
# [922]	train-rmse:3.83653	test-rmse:4.85783
# [923]	train-rmse:3.83608	test-rmse:4.85741
# [924]	train-rmse:3.83574	test-rmse:4.85695
# [925]	train-rmse:3.83543	test-rmse:4.85655
# [926]	train-rmse:3.83456	test-rmse:4.85599
# [927]	train-rmse:3.83399	test-rmse:4.85578
# [928]	train-rmse:3.83303	test-rmse:4.85601
# [929]	train-rmse:3.83268	test-rmse:4.85585
# [930]	train-rmse:3.83205	test-rmse:4.85539
# [931]	train-rmse:3.83104	test-rmse:4.85517
# [932]	train-rmse:3.83056	test-rmse:4.85439
# [933]	train-rmse:3.82996	test-rmse:4.85414
# [934]	train-rmse:3.82955	test-rmse:4.85398
# [935]	train-rmse:3.82685	test-rmse:4.85377
# [936]	train-rmse:3.82618	test-rmse:4.85227
# [937]	train-rmse:3.82578	test-rmse:4.85191
# [938]	train-rmse:3.82545	test-rmse:4.85162
# [939]	train-rmse:3.8251	test-rmse:4.85151
# [940]	train-rmse:3.82462	test-rmse:4.85118
# [941]	train-rmse:3.82408	test-rmse:4.85094
# [942]	train-rmse:3.8237	test-rmse:4.8501
# [943]	train-rmse:3.82284	test-rmse:4.84989
# [944]	train-rmse:3.82248	test-rmse:4.84962
# [945]	train-rmse:3.82187	test-rmse:4.84936
# [946]	train-rmse:3.82132	test-rmse:4.84909
# [947]	train-rmse:3.82087	test-rmse:4.84889
# [948]	train-rmse:3.82008	test-rmse:4.84726
# [949]	train-rmse:3.8189	test-rmse:4.84853
# [950]	train-rmse:3.81857	test-rmse:4.84831
# [951]	train-rmse:3.8179	test-rmse:4.84809
# [952]	train-rmse:3.81743	test-rmse:4.8479
# [953]	train-rmse:3.81611	test-rmse:4.84573
# [954]	train-rmse:3.81539	test-rmse:4.84598
# [955]	train-rmse:3.81511	test-rmse:4.84582
# [956]	train-rmse:3.81478	test-rmse:4.84571
# [957]	train-rmse:3.81455	test-rmse:4.84558
# [958]	train-rmse:3.81356	test-rmse:4.84498
# [959]	train-rmse:3.81269	test-rmse:4.84613
# [960]	train-rmse:3.81159	test-rmse:4.8458
# [961]	train-rmse:3.81125	test-rmse:4.84568
# [962]	train-rmse:3.8111	test-rmse:4.84561
# [963]	train-rmse:3.81087	test-rmse:4.84558

# %%
model_1
# Out:
#      train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0           8.175192        0.226822        8.135778       0.899370
# 1           7.866800        0.222125        7.832152       0.878476
# 2           7.608992        0.216531        7.580255       0.867566
# 3           7.393505        0.214725        7.370764       0.854560
# 4           7.209263        0.211733        7.187895       0.852783
# 5           7.058324        0.213192        7.040357       0.845423
# 6           6.933207        0.221954        6.925748       0.838595
# 7           6.824641        0.217021        6.827521       0.848070
# 8           6.723354        0.211403        6.741054       0.848490
# 9           6.641220        0.220266        6.662170       0.827373
# 10          6.573699        0.218027        6.601776       0.826171
# 11          6.499894        0.210161        6.538297       0.818938
# 12          6.438000        0.211242        6.488614       0.815237
# 13          6.383630        0.208564        6.446364       0.813795
# 14          6.336936        0.204835        6.407117       0.814622
# 15          6.291580        0.206172        6.363818       0.799032
# 16          6.249709        0.202683        6.332975       0.795762
# 17          6.215015        0.204582        6.298927       0.790234
# 18          6.187449        0.200344        6.278340       0.787514
# 19          6.150755        0.204009        6.251375       0.790554
# 20          6.118482        0.201429        6.222226       0.792282
# 21          6.075777        0.201472        6.183341       0.782559
# 22          6.026874        0.217624        6.143450       0.775821
# 23          5.997301        0.217343        6.119457       0.780180
# 24          5.974890        0.214945        6.103754       0.783734
# 25          5.945697        0.216149        6.078424       0.788924
# 26          5.919780        0.207008        6.057383       0.789432
# 27          5.895639        0.207588        6.041785       0.791601
# 28          5.870568        0.209995        6.025834       0.792256
# 29          5.849440        0.204602        6.004346       0.795333
# ..               ...             ...             ...            ...
# 929         3.832684        0.093062        4.855847       0.795850
# 930         3.832045        0.093041        4.855390       0.796202
# 931         3.831043        0.093059        4.855173       0.796367
# 932         3.830556        0.092865        4.854392       0.796883
# 933         3.829961        0.093054        4.854136       0.797123
# 934         3.829551        0.093122        4.853977       0.797070
# 935         3.826845        0.094770        4.853772       0.797139
# 936         3.826177        0.094905        4.852267       0.795384
# 937         3.825782        0.094898        4.851907       0.795385
# 938         3.825448        0.094907        4.851624       0.795437
# 939         3.825103        0.095010        4.851511       0.795418
# 940         3.824621        0.095045        4.851176       0.795461
# 941         3.824083        0.095024        4.850944       0.795521
# 942         3.823702        0.095071        4.850097       0.795295
# 943         3.822843        0.094563        4.849891       0.795358
# 944         3.822479        0.094317        4.849624       0.795481
# 945         3.821875        0.094394        4.849358       0.795710
# 946         3.821315        0.094672        4.849092       0.795664
# 947         3.820869        0.094692        4.848892       0.795646
# 948         3.820080        0.094782        4.847259       0.794098
# 949         3.818902        0.095474        4.848532       0.794146
# 950         3.818573        0.095621        4.848312       0.794091
# 951         3.817903        0.095305        4.848090       0.794286
# 952         3.817431        0.095004        4.847903       0.794427
# 953         3.816112        0.094888        4.845732       0.794920
# 954         3.815389        0.094449        4.845980       0.794454
# 955         3.815110        0.094280        4.845818       0.794617
# 956         3.814785        0.094147        4.845714       0.794664
# 957         3.814550        0.094242        4.845585       0.794637
# 958         3.813559        0.094715        4.844975       0.794434
#
# [959 rows x 4 columns]

# %%
model_2 = xgb.train(params=xgb_params,
                    dtrain=xgb_train_data,
                    num_boost_round=958)

# %%
model_2

# %%
validation_predictions = model_2.predict(xgb_validation_data)

# %%
np.sqrt(mean_squared_error(np.clip(validation_predictions, 0 , 20),  np.clip(new_Y, 0, 20)))
# Out:
# 2.0723484427163665

# %% [markdown]
# ##### That looks like a reasonably good jump !!! I am not sure what else we can do with xgboost. Let us generate predictions on the test set now.

# %%
test = pd.read_csv('input/test.csv')

# %%
test.head()
# Out:
#    ID  shop_id  item_id
# 0   0        5     5037
# 1   1        5     5320
# 2   2        5     5233
# 3   3        5     5232
# 4   4        5     5268

# %%
test['date_block_num'] = 33

# %%
test['item_category_id'] = test['item_id'].apply(lambda x : item_id_to_item_category_id.get(x, -1))

# %%
test['item_category_id'].describe()
# Out:
# count    214200.000000
# mean         46.309608
# std          16.716581
# min           0.000000
# 25%          37.000000
# 50%          43.000000
# 75%          58.000000
# max          83.000000
# Name: item_category_id, dtype: float64

# %%
test.head()
# Out:
#    ID  shop_id  item_id  date_block_num  item_category_id
# 0   0        5     5037              33                19
# 1   1        5     5320              33                55
# 2   2        5     5233              33                19
# 3   3        5     5232              33                23
# 4   4        5     5268              33                20

# %%
test_X = test[X_COLUMNS]

# %%
xgb_test_predictions = xgb.DMatrix(test_X, feature_names=X_COLUMNS)

# %%
test_predictions = model_2.predict(xgb_test_predictions)

# %%
test_predictions
# Out:
# array([1.6810371, 2.7009327, 1.9303876, ..., 1.0022887, 1.0603472,
#        1.0034266], dtype=float32)

# %%
test['item_cnt_month'] = np.clip(test_predictions, 0, 20)

# %%
test[['ID', 'item_cnt_month']].to_csv('submissions/submission_xgboost.csv', index=False)
